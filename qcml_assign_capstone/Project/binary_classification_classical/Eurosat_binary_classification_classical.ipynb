# %% [markdown]
# # Introduction

# %% [markdown]
# The source code below, demonstrates the usage of CNN LeNet-5 architecture for two classes 1,2.

# %% [markdown]
# # Runtime req

# %%
# !nvidia-smi
# Out:
# Fri Jul 21 02:10:02 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    27W /  70W |   1515MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Install appropriate run time and prepare the dataset.

# %%
# !pip install -q torch
# !pip install -q matplotlib
# !pip install -q visualkeras
# !unzip -q "/content/drive/MyDrive/colab_notebooks/IITD-QML/EuroSAT_RGB.zip"
# Out:
# replace EuroSAT_RGB/Forest/Forest_864.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %% [markdown]
# Configure runtime to make sure that the imports are working well.

# %%
import sys
import numpy as np
import random
import torch
import glob
import os
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Activation, Flatten, MaxPool2D, BatchNormalization, AveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tqdm import tqdm
from matplotlib import pyplot as plt
from torch.autograd import Function
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
# %matplotlib inline

sys.path.append('/content/drive/MyDrive/colab_notebooks/IITD-QML/')
dataset_root_path = '/content/EuroSAT_RGB'

# %% [markdown]
# Discover the root path for all the classes present in folder hierarchy.

# %% [markdown]
# # Classical CNN

# %%
kernel_size = 3
stride = 1

model = Sequential()
model.add(Conv2D(16, kernel_size=kernel_size, strides=stride, activation='relu', padding='same', input_shape = (64,64,3)))
model.add(AveragePooling2D())
model.add(Conv2D(32, kernel_size=kernel_size, strides=stride, activation='relu', padding='valid'))
model.add(AveragePooling2D())
model.add(Conv2D(64, kernel_size=kernel_size, strides=stride, activation='relu', padding='valid'))
model.add(AveragePooling2D())

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer=SGD(learning_rate=0.0002), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 64, 64, 16)        448
#
#  average_pooling2d_3 (Averag  (None, 32, 32, 16)       0
#  ePooling2D)
#
#  conv2d_4 (Conv2D)           (None, 30, 30, 32)        4640
#
#  average_pooling2d_4 (Averag  (None, 15, 15, 32)       0
#  ePooling2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 64)        18496
#
#  average_pooling2d_5 (Averag  (None, 6, 6, 64)         0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_4 (Dense)             (None, 128)               295040
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dense_7 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 329,026
# Trainable params: 329,026
# Non-trainable params: 0
# _________________________________________________________________

# %%
import glob
import os
import numpy as np
import random

class DatasetHandler:
    def __init__(self, ds_root_path):
        print ('Datahandler init -> ', ds_root_path)
        self.dataset_path = ds_root_path
        self.classes = glob.glob(os.path.join(ds_root_path, '*'))
        self.classes_dict = {}
        for c, i in zip(self.classes, range(len(self.classes))):
          self.classes_dict[c] = i

    def print_classes(self):
        print('Classes in the path: ')
        for i,c in enumerate(self.classes):
            print(i, ' ->', c)

    def load_paths_labels(self, root, classes):
        imgs_path = []
        imgs_label = []

        for clss in self.classes[:2]:
            for path in glob.glob(os.path.join(root, clss+'/*')):
              imgs_path.append(path)
              imgs_label.append(self.classes_dict[clss])

        dataset = list(zip(imgs_path, imgs_label))
        random.shuffle(dataset)
        paths, labels = zip(*dataset)
        return np.array(paths), np.array(labels)

    # Split the dataset into training and validation dataset
    def train_validation_split(self, images, labels, split_factor = 0.2):
        val_size = int(len(images)*split_factor)
        train_size = int(len(images) - val_size)
        return images[0:train_size], labels[0:train_size, ...], images[train_size:train_size+val_size], labels[train_size:train_size+val_size, ...]

    # Data genertor: given images paths and images labels yield a batch of images and labels
    def cnn_data_loader(self, imgs_path, imgs_label, batch_size = 16, img_shape = (64, 64, 3), n_classes = 2):
        # Initialize the vectors to be yield
        batch_in = np.zeros((batch_size, img_shape[0], img_shape[1], img_shape[2]))
        batch_out = np.zeros((batch_size, n_classes))
        # Repeat until the generator will be stopped
        while True:
            # Load a batch of images and labels
            for i in range(batch_size):
                # Select a random image and labels from the dataset
                index = random.randint(0, len(imgs_path)-1)
                # Fill the vectors with images and labels
                batch_in[i, ...] = plt.imread(imgs_path[index])/255.0
                l = np.zeros((n_classes))
                l[imgs_label[index]] = 1
                batch_out[i, ...] = l

            # Yield/Return the image and labeld vectors
            yield batch_in, batch_out

# %%
handler = DatasetHandler(dataset_root_path)
imgs_path, imgs_label = handler.load_paths_labels(dataset_root_path, handler.classes[:2])
print('Dataset images:', len(imgs_path), 'Dataset labels:', len(imgs_label))
print('Dataset sample ->', imgs_path[0], imgs_label[0])
# Out:
# Datahandler init ->  /content/EuroSAT_RGB
# Dataset images: 5500 Dataset labels: 5500
# Dataset sample -> /content/EuroSAT_RGB/Residential/Residential_1945.jpg 0

# %%
train_imgs, train_labels, val_images, val_labels = handler.train_validation_split(imgs_path, imgs_label, split_factor=0.2)
print('X_train shape:', train_imgs.shape, 'Y_train shape:', train_labels.shape)
print('  X_val shape: ', val_images.shape, '  Y_val shape: ', val_labels.shape)
# Out:
# X_train shape: (4400,) Y_train shape: (4400,)
#   X_val shape:  (1100,)   Y_val shape:  (1100,)

# %%
def plotDataset(images, labels, classes, columns, rows):
    fig, axes = plt.subplots(nrows = rows, ncols = columns, figsize = (columns*4,rows*4))
    for x in range(columns):
        for y in range(rows):
            index = random.randint(0, len(images)-1)

            axes[y,x].imshow(plt.imread(images[index]))
            axes[y,x].set_title('Label: ' + str(labels[index]) +
                                '\n Class: ' + classes[labels[index]].split('/')[-1])
            axes[y,x].axis(False)

    plt.show()

# %%
plotDataset(train_imgs, train_labels, handler.classes, columns = 5, rows = 2)

# %%
batch_size = 1
epochs = 100

train_gen = handler.cnn_data_loader(train_imgs, train_labels, batch_size=batch_size, img_shape=(64,64,3), n_classes=2)
val_gen = handler.cnn_data_loader(val_images, val_labels, batch_size=batch_size, img_shape=(64,64,3), n_classes=2)

es = EarlyStopping(monitor='val_loss', min_delta=0, patience=15, verbose=0, mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(train_gen,
                            steps_per_epoch = len(train_labels)//batch_size,
                            epochs = epochs,
                            validation_data = val_gen,
                            validation_steps = len(val_labels)//batch_size,
                            callbacks = [es])
# Out:
# Epoch 1/100
# 4400/4400 [==============================] - 31s 6ms/step - loss: 0.6771 - accuracy: 0.5798 - val_loss: 0.6688 - val_accuracy: 0.7091
# Epoch 2/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.6415 - accuracy: 0.7061 - val_loss: 0.6104 - val_accuracy: 0.7164
# Epoch 3/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.5914 - accuracy: 0.7105 - val_loss: 0.6157 - val_accuracy: 0.6664
# Epoch 4/100
# 4400/4400 [==============================] - 29s 6ms/step - loss: 0.5236 - accuracy: 0.7543 - val_loss: 0.4984 - val_accuracy: 0.7600
# Epoch 5/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.4691 - accuracy: 0.7877 - val_loss: 0.4209 - val_accuracy: 0.8200
# Epoch 6/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.4396 - accuracy: 0.8111 - val_loss: 0.4361 - val_accuracy: 0.8155
# Epoch 7/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.4015 - accuracy: 0.8325 - val_loss: 0.3376 - val_accuracy: 0.8836
# Epoch 8/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.3940 - accuracy: 0.8395 - val_loss: 0.3479 - val_accuracy: 0.8764
# Epoch 9/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.3651 - accuracy: 0.8580 - val_loss: 0.3539 - val_accuracy: 0.8645
# Epoch 10/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.3530 - accuracy: 0.8586 - val_loss: 0.3041 - val_accuracy: 0.9027
# Epoch 11/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.3151 - accuracy: 0.8759 - val_loss: 0.2670 - val_accuracy: 0.9009
# Epoch 12/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.2884 - accuracy: 0.8957 - val_loss: 0.5626 - val_accuracy: 0.7418
# Epoch 13/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.2984 - accuracy: 0.8864 - val_loss: 0.4535 - val_accuracy: 0.7909
# Epoch 14/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.2840 - accuracy: 0.8984 - val_loss: 0.2226 - val_accuracy: 0.9291
# Epoch 15/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.2628 - accuracy: 0.9077 - val_loss: 0.2201 - val_accuracy: 0.9318
# Epoch 16/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.2633 - accuracy: 0.9043 - val_loss: 0.6629 - val_accuracy: 0.7264
# Epoch 17/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.2481 - accuracy: 0.9139 - val_loss: 0.1916 - val_accuracy: 0.9427
# Epoch 18/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.2473 - accuracy: 0.9166 - val_loss: 0.1746 - val_accuracy: 0.9482
# Epoch 19/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.2462 - accuracy: 0.9141 - val_loss: 0.2053 - val_accuracy: 0.9336
# Epoch 20/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.2269 - accuracy: 0.9239 - val_loss: 0.1736 - val_accuracy: 0.9500
# Epoch 21/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.2268 - accuracy: 0.9214 - val_loss: 0.1832 - val_accuracy: 0.9427
# Epoch 22/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.2041 - accuracy: 0.9323 - val_loss: 0.2245 - val_accuracy: 0.9109
# Epoch 23/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.2179 - accuracy: 0.9252 - val_loss: 0.1835 - val_accuracy: 0.9455
# Epoch 24/100
# 4400/4400 [==============================] - 29s 6ms/step - loss: 0.2161 - accuracy: 0.9305 - val_loss: 0.1664 - val_accuracy: 0.9527
# Epoch 25/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.2331 - accuracy: 0.9186 - val_loss: 0.1600 - val_accuracy: 0.9655
# Epoch 26/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.2171 - accuracy: 0.9245 - val_loss: 0.2012 - val_accuracy: 0.9282
# Epoch 27/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.2149 - accuracy: 0.9248 - val_loss: 0.1732 - val_accuracy: 0.9473
# Epoch 28/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.2074 - accuracy: 0.9282 - val_loss: 0.1507 - val_accuracy: 0.9500
# Epoch 29/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.1955 - accuracy: 0.9364 - val_loss: 0.1625 - val_accuracy: 0.9464
# Epoch 30/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.1906 - accuracy: 0.9357 - val_loss: 0.1460 - val_accuracy: 0.9600
# Epoch 31/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.2009 - accuracy: 0.9314 - val_loss: 0.1579 - val_accuracy: 0.9573
# Epoch 32/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.2005 - accuracy: 0.9341 - val_loss: 0.1323 - val_accuracy: 0.9564
# Epoch 33/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.1725 - accuracy: 0.9439 - val_loss: 0.1595 - val_accuracy: 0.9545
# Epoch 34/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.1766 - accuracy: 0.9414 - val_loss: 0.1984 - val_accuracy: 0.9300
# Epoch 35/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.1874 - accuracy: 0.9350 - val_loss: 0.1428 - val_accuracy: 0.9500
# Epoch 36/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.1728 - accuracy: 0.9393 - val_loss: 0.1860 - val_accuracy: 0.9345
# Epoch 37/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.1720 - accuracy: 0.9455 - val_loss: 0.1638 - val_accuracy: 0.9436
# Epoch 38/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.1665 - accuracy: 0.9434 - val_loss: 0.1767 - val_accuracy: 0.9409
# Epoch 39/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.1621 - accuracy: 0.9461 - val_loss: 0.1700 - val_accuracy: 0.9364
# Epoch 40/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.1609 - accuracy: 0.9425 - val_loss: 0.1161 - val_accuracy: 0.9655
# Epoch 41/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.1577 - accuracy: 0.9477 - val_loss: 0.1254 - val_accuracy: 0.9527
# Epoch 42/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.1587 - accuracy: 0.9427 - val_loss: 0.0948 - val_accuracy: 0.9700
# Epoch 43/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.1426 - accuracy: 0.9502 - val_loss: 0.2907 - val_accuracy: 0.8991
# Epoch 44/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.1292 - accuracy: 0.9539 - val_loss: 0.1128 - val_accuracy: 0.9618
# Epoch 45/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.1290 - accuracy: 0.9523 - val_loss: 0.2221 - val_accuracy: 0.9064
# Epoch 46/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.1181 - accuracy: 0.9584 - val_loss: 0.0885 - val_accuracy: 0.9682
# Epoch 47/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.1146 - accuracy: 0.9602 - val_loss: 0.0791 - val_accuracy: 0.9755
# Epoch 48/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.1049 - accuracy: 0.9650 - val_loss: 0.0911 - val_accuracy: 0.9727
# Epoch 49/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.1169 - accuracy: 0.9570 - val_loss: 0.0790 - val_accuracy: 0.9736
# Epoch 50/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.0867 - accuracy: 0.9698 - val_loss: 0.2304 - val_accuracy: 0.9027
# Epoch 51/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.1022 - accuracy: 0.9618 - val_loss: 0.0855 - val_accuracy: 0.9700
# Epoch 52/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0914 - accuracy: 0.9664 - val_loss: 0.1008 - val_accuracy: 0.9691
# Epoch 53/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.0931 - accuracy: 0.9652 - val_loss: 0.1276 - val_accuracy: 0.9536
# Epoch 54/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0784 - accuracy: 0.9739 - val_loss: 0.0622 - val_accuracy: 0.9800
# Epoch 55/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0877 - accuracy: 0.9684 - val_loss: 0.1857 - val_accuracy: 0.9327
# Epoch 56/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.0825 - accuracy: 0.9702 - val_loss: 0.0979 - val_accuracy: 0.9691
# Epoch 57/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0762 - accuracy: 0.9727 - val_loss: 0.1649 - val_accuracy: 0.9336
# Epoch 58/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0790 - accuracy: 0.9720 - val_loss: 0.0773 - val_accuracy: 0.9764
# Epoch 59/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0773 - accuracy: 0.9702 - val_loss: 0.0723 - val_accuracy: 0.9709
# Epoch 60/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.0770 - accuracy: 0.9741 - val_loss: 0.0486 - val_accuracy: 0.9827
# Epoch 61/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.0764 - accuracy: 0.9711 - val_loss: 0.0651 - val_accuracy: 0.9736
# Epoch 62/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.0667 - accuracy: 0.9775 - val_loss: 0.0517 - val_accuracy: 0.9818
# Epoch 63/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.0625 - accuracy: 0.9780 - val_loss: 0.0704 - val_accuracy: 0.9718
# Epoch 64/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.0600 - accuracy: 0.9791 - val_loss: 0.0784 - val_accuracy: 0.9700
# Epoch 65/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.0580 - accuracy: 0.9798 - val_loss: 0.0604 - val_accuracy: 0.9773
# Epoch 66/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.0684 - accuracy: 0.9766 - val_loss: 0.0829 - val_accuracy: 0.9673
# Epoch 67/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0641 - accuracy: 0.9761 - val_loss: 0.0483 - val_accuracy: 0.9855
# Epoch 68/100
# 4400/4400 [==============================] - 30s 7ms/step - loss: 0.0483 - accuracy: 0.9816 - val_loss: 0.1849 - val_accuracy: 0.9373
# Epoch 69/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0603 - accuracy: 0.9768 - val_loss: 0.0458 - val_accuracy: 0.9800
# Epoch 70/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0563 - accuracy: 0.9795 - val_loss: 0.0405 - val_accuracy: 0.9864
# Epoch 71/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0561 - accuracy: 0.9791 - val_loss: 0.0437 - val_accuracy: 0.9800
# Epoch 72/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.0576 - accuracy: 0.9770 - val_loss: 0.0513 - val_accuracy: 0.9800
# Epoch 73/100
# 4400/4400 [==============================] - 26s 6ms/step - loss: 0.0438 - accuracy: 0.9859 - val_loss: 0.0589 - val_accuracy: 0.9809
# Epoch 74/100
# 4400/4400 [==============================] - 31s 7ms/step - loss: 0.0507 - accuracy: 0.9816 - val_loss: 0.1616 - val_accuracy: 0.9345
# Epoch 75/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0530 - accuracy: 0.9800 - val_loss: 0.0394 - val_accuracy: 0.9836
# Epoch 76/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0530 - accuracy: 0.9809 - val_loss: 0.0295 - val_accuracy: 0.9873
# Epoch 77/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0483 - accuracy: 0.9818 - val_loss: 0.0626 - val_accuracy: 0.9800
# Epoch 78/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0477 - accuracy: 0.9818 - val_loss: 0.0450 - val_accuracy: 0.9791
# Epoch 79/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0517 - accuracy: 0.9816 - val_loss: 0.0492 - val_accuracy: 0.9791
# Epoch 80/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0531 - accuracy: 0.9807 - val_loss: 0.2027 - val_accuracy: 0.9291
# Epoch 81/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0428 - accuracy: 0.9864 - val_loss: 0.0380 - val_accuracy: 0.9836
# Epoch 82/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0464 - accuracy: 0.9841 - val_loss: 0.0538 - val_accuracy: 0.9800
# Epoch 83/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0391 - accuracy: 0.9870 - val_loss: 0.2230 - val_accuracy: 0.9136
# Epoch 84/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0387 - accuracy: 0.9880 - val_loss: 0.0263 - val_accuracy: 0.9909
# Epoch 85/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.0322 - accuracy: 0.9889 - val_loss: 0.0346 - val_accuracy: 0.9882
# Epoch 86/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0543 - accuracy: 0.9789 - val_loss: 0.0320 - val_accuracy: 0.9882
# Epoch 87/100
# 4400/4400 [==============================] - 30s 7ms/step - loss: 0.0358 - accuracy: 0.9880 - val_loss: 0.0455 - val_accuracy: 0.9791
# Epoch 88/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0301 - accuracy: 0.9889 - val_loss: 0.0408 - val_accuracy: 0.9845
# Epoch 89/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0450 - accuracy: 0.9852 - val_loss: 0.0512 - val_accuracy: 0.9818
# Epoch 90/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0366 - accuracy: 0.9868 - val_loss: 0.0696 - val_accuracy: 0.9736
# Epoch 91/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0357 - accuracy: 0.9873 - val_loss: 0.0410 - val_accuracy: 0.9818
# Epoch 92/100
# 4400/4400 [==============================] - 30s 7ms/step - loss: 0.0210 - accuracy: 0.9930 - val_loss: 0.0998 - val_accuracy: 0.9727
# Epoch 93/100
# 4400/4400 [==============================] - 29s 6ms/step - loss: 0.0382 - accuracy: 0.9859 - val_loss: 0.0256 - val_accuracy: 0.9873
# Epoch 94/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0329 - accuracy: 0.9866 - val_loss: 0.0331 - val_accuracy: 0.9882
# Epoch 95/100
# 4400/4400 [==============================] - 29s 7ms/step - loss: 0.0275 - accuracy: 0.9898 - val_loss: 0.0598 - val_accuracy: 0.9818
# Epoch 96/100
# 4400/4400 [==============================] - 27s 6ms/step - loss: 0.0310 - accuracy: 0.9895 - val_loss: 0.0258 - val_accuracy: 0.9873
# Epoch 97/100
# 4400/4400 [==============================] - 30s 7ms/step - loss: 0.0421 - accuracy: 0.9841 - val_loss: 0.0315 - val_accuracy: 0.9855
# Epoch 98/100
# 4400/4400 [==============================] - 28s 6ms/step - loss: 0.0251 - accuracy: 0.9918 - val_loss: 0.0279 - val_accuracy: 0.9873
# Epoch 99/100
# 4400/4400 [==============================] - 30s 7ms/step - loss: 0.0310 - accuracy: 0.9895 - val_loss: 0.1091 - val_accuracy: 0.9682
# Epoch 100/100
# 4400/4400 [==============================] - 30s 7ms/step - loss: 0.0313 - accuracy: 0.9891 - val_loss: 0.0454 - val_accuracy: 0.9855

# %%
model.save(os.path.join('trained_models', 'CNN-binary-classification.h5'))

# %%
def plotCNNhistory(history):
    x = np.arange(0, len(history.history['accuracy']))

    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(9, 10))

    axes[0].plot(x, history.history['accuracy'], '-*')
    axes[0].plot(x, history.history['val_accuracy'], '-o')
    axes[0].legend(['Training Accuracy', 'Validation Accuracy'], fontsize = 14)
    axes[0].set_title('Training and Validation Accuracy', fontsize=20)
    axes[0].set_xlabel('Epochs', fontsize = 14)
    axes[0].set_ylabel('Accuracy', fontsize = 14)
    axes[0].set_ylim([0,1])
    axes[0].grid()

    axes[1].plot(x, history.history['loss'], '-*')
    axes[1].plot(x, history.history['val_loss'], '-o')
    axes[1].legend(['Training Loss', 'Validation Loss'], fontsize = 14)
    axes[1].set_title('Training and Validation loss', fontsize = 20)
    axes[1].set_xlabel('Epochs', fontsize = 14)
    axes[1].set_ylabel('Loss', fontsize = 14)
    axes[1].set_ylim([0,None])
    axes[1].grid()

    fig.tight_layout()
    plt.show()

plotCNNhistory(history)

# %%
import keras
keras.utils.plot_model(model, "multi_input_and_output_model.png", show_shapes=True,show_dtype=True, show_layer_names=True, show_layer_activations=True, show_trainable=True)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import visualkeras
visualkeras.layered_view(model, legend=True,)
# Out:
# <PIL.Image.Image image mode=RGBA size=597x378 at 0x79FDFF2C75E0>
