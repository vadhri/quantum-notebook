# %%
import json
import pennylane as qml
import pennylane.numpy as np

edges = [(0, 1), (1, 2), (2, 0), (2, 3)]
num_wires = 4

# We define the Hamiltonian for you!

ops = [qml.PauliZ(0), qml.PauliZ(1),qml.PauliZ(2), qml.PauliZ(3), qml.PauliZ(0)@qml.PauliZ(1), qml.PauliZ(0)@qml.PauliZ(2),qml.PauliZ(1)@qml.PauliZ(2),qml.PauliZ(2)@qml.PauliZ(3)]
coeffs = [0.5, 0.5, 1.25, -0.25, 0.75, 0.75, 0.75, 0.75]

cost_hamiltonian = qml.Hamiltonian(coeffs, ops)

# Write any helper functions you need here
true_value = np.min(np.linalg.eigvalsh(cost_hamiltonian.sparse_matrix().todense()))

dev = qml.device('default.mixed', wires = num_wires)

@qml.qnode(dev) 
def qaoa_circuit(gammabeta, noise_param):

    for i in range(num_wires):
        qml.RY(np.pi/2, i)

    for param in gammabeta: 
        gamma, alpha = param
        gamma /= 2
        alpha /= 2
        qml.RZ(2*gamma*0.5, wires=0)
        qml.RZ(2*gamma*0.5, wires=1)
        qml.RZ(2*gamma*1.25, wires=2)
        qml.RZ(2*gamma*-0.25, wires=3)

        qml.CNOT(wires=[0,1])
        # qml.DepolarizingChannel(noise_param, wires=1)

        qml.RZ(2*gamma*0.75, 1)
        qml.CNOT(wires=[0,1])
        qml.DepolarizingChannel(noise_param, wires=1)

        qml.CNOT(wires=[0,2])
        # qml.DepolarizingChannel(noise_param, wires=2)

        qml.RZ(2*gamma*0.75, 2)
        qml.CNOT(wires=[0,2])
        # qml.DepolarizingChannel(noise_param, wires=2)

        qml.CNOT(wires=[1,2])
        # qml.DepolarizingChannel(noise_param, wires=2)

        qml.RZ(2*gamma*0.75, 2)
        qml.CNOT(wires=[1,2])    
        qml.DepolarizingChannel(noise_param, wires=2)

        qml.CNOT(wires=[2,3])
        qml.RZ(2*gamma*0.75, 3)
        qml.CNOT(wires=[2,3])                    
        qml.DepolarizingChannel(noise_param, wires=3)

        for i in range(num_wires):
            qml.RX(2*alpha, wires=i)      

        return qml.expval(cost_hamiltonian)

def approximation_ratio(qaoa_depth, noise_param):
    params = np.array([[0.5, 0.5]], requires_grad=True)
    np.repeat(params,qaoa_depth,axis=0)    
    print ("approximation_ratio : ", qaoa_depth, noise_param, params)
    
    def cost_function(p):
        return qaoa_circuit(np.repeat(p, qaoa_depth, axis=0), noise_param)
    
    opt = qml.AdamOptimizer(stepsize=0.1)

    for it in range(500):
        params, cost = opt.step_and_cost(cost_function, params)
        if it % 50 == 0:
            print (it, " iter, cost = ", cost, cost/true_value, params)

    # qml.draw_mpl(qaoa_circuit, decimals=2)(params, 0)

    minval = cost_function(params)
    return minval/true_value

random_params = np.array([np.random.rand(2)])

ops_2 = [qml.PauliX(0), qml.PauliX(1), qml.PauliX(2), qml.PauliX(3)]
coeffs_2 = [1,1,1,1]

mixer_hamiltonian = qml.Hamiltonian(coeffs_2, ops_2)

@qml.qnode(dev)
def noiseless_qaoa(params):
    for wire in range(num_wires):
        qml.Hadamard(wires = wire)

    for elem in params:
        qml.ApproxTimeEvolution(cost_hamiltonian, elem[0], 1)
        qml.ApproxTimeEvolution(mixer_hamiltonian, elem[1],1)

    return qml.expval(cost_hamiltonian)

random_params = np.array([np.random.rand(2)])
circuit_check = (np.isclose(noiseless_qaoa(random_params) - qaoa_circuit(random_params,0),0)).numpy()

def run(test_case_input: str) -> str:
    input = json.loads(test_case_input)

    output = approximation_ratio(*input)
    print ("Run output === ", output)
    return str(output)

def check(solution_output: str, expected_output: str) -> None:
    solution_output = json.loads(solution_output)
    expected_output = json.loads(expected_output)
    print (solution_output, expected_output)
    tape = qaoa_circuit.qtape
    names = [op.name for op in tape.operations]
    random_params = np.array([np.random.rand(2)])
    assert circuit_check, "qaoa_circuit is not doing what it's expected to."

    assert names.count('ApproxTimeEvolution') == 0, "Your circuit must not use the built-in PennyLane Trotterization."
     
    assert set(names) == {'DepolarizingChannel', 'RX', 'RY', 'RZ', 'CNOT'}, "Your circuit must use qml.RX, qml.RY, qml.RZ, qml.CNOT, and qml.DepolarizingChannel."

    assert solution_output > expected_output - 0.02


# These are the public test cases
test_cases = [
    ('[1, 0.003]', '0.1307'),
    ('[2,0.005]', '0.4875'),
]

# This will run the public test cases locally
for i, (input_, expected_output) in enumerate(test_cases):
    print(f"Running test case {i} with input '{input_}'...")

    try:
        output = run(input_)

    except Exception as exc:
        print(f"Runtime Error. {exc}")

    else:
        if message := check(output, expected_output):
            print(f"Wrong Answer. Have: '{output}'. Want: '{expected_output}'.")

        else:
            print("Correct!")
# Out:
# Running test case 0 with input '[1, 0.003]'...
# approximation_ratio :  1 0.003 [[0.5 0.5]]
# 0  iter, cost =  1.2622665707284622 -0.42075552357615403 [[0.40000001 0.4       ]]
# 50  iter, cost =  -1.328582992615598 0.4428609975385327 [[-0.70586321  0.91675101]]
# 100  iter, cost =  -1.4036017427635081 0.46786724758783604 [[-0.67505169  0.79565453]]
# 150  iter, cost =  -1.4043856161373511 0.46812853871245036 [[-0.69532114  0.79469475]]
# 200  iter, cost =  -1.4043882787939714 0.46812942626465714 [[-0.69509566  0.79423977]]
# 250  iter, cost =  -1.4043883016193837 0.4681294338731279 [[-0.69520925  0.79425241]]
# 300  iter, cost =  -1.4043883017077157 0.4681294339025719 [[-0.69521148  0.79424741]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 142
#     139 print(f"Running test case {i} with input '{input_}'...")
#     141 try:
# --> 142     output = run(input_)
#     144 except Exception as exc:
#     145     print(f"Runtime Error. {exc}")
#
# Cell In[58], line 111, in run(test_case_input)
#     108 def run(test_case_input: str) -> str:
#     109     input = json.loads(test_case_input)
# --> 111     output = approximation_ratio(*input)
#     112     print ("Run output === ", output)
#     113     return str(output)
#
# Cell In[58], line 78, in approximation_ratio(qaoa_depth, noise_param)
#      75 opt = qml.AdamOptimizer(stepsize=0.1)
#      77 for it in range(500):
# ---> 78     params, cost = opt.step_and_cost(cost_function, params)
#      79     if it % 50 == 0:
#      80         print (it, " iter, cost = ", cost, cost/true_value, params)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/optimize/gradient_descent.py:59, in GradientDescentOptimizer.step_and_cost(self, objective_fn, grad_fn, *args, **kwargs)
#      39 def step_and_cost(self, objective_fn, *args, grad_fn=None, **kwargs):
#      40     """Update trainable arguments with one step of the optimizer and return the corresponding
#      41     objective function value prior to the step.
#      42
#    (...)
#      56         If single arg is provided, list [array] is replaced by array.
#      57     """
# ---> 59     g, forward = self.compute_grad(objective_fn, args, kwargs, grad_fn=grad_fn)
#      60     new_args = self.apply_grad(g, args)
#      62     if forward is None:
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/optimize/gradient_descent.py:117, in GradientDescentOptimizer.compute_grad(objective_fn, args, kwargs, grad_fn)
#      99 r"""Compute gradient of the objective function at the given point and return it along with
#     100 the objective function forward pass (if available).
#     101
#    (...)
#     114     will not be evaluted and instead ``None`` will be returned.
#     115 """
#     116 g = get_gradient(objective_fn) if grad_fn is None else grad_fn
# --> 117 grad = g(*args, **kwargs)
#     118 forward = getattr(g, "forward", None)
#     120 num_trainable_args = sum(getattr(arg, "requires_grad", False) for arg in args)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/_grad.py:117, in grad.__call__(self, *args, **kwargs)
#     114     self._forward = self._fun(*args, **kwargs)
#     115     return ()
# --> 117 grad_value, ans = grad_fn(*args, **kwargs)  # pylint: disable=not-callable
#     118 self._forward = ans
#     120 return grad_value
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/autograd/wrap_util.py:20, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f(*args, **kwargs)
#      18 else:
#      19     x = tuple(args[i] for i in argnum)
# ---> 20 return unary_operator(unary_f, x, *nary_op_args, **nary_op_kwargs)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/_grad.py:135, in grad._grad_with_forward(fun, x)
#     129 @staticmethod
#     130 @unary_to_nary
#     131 def _grad_with_forward(fun, x):
#     132     """This function is a replica of ``autograd.grad``, with the only
#     133     difference being that it returns both the gradient *and* the forward pass
#     134     value."""
# --> 135     vjp, ans = _make_vjp(fun, x)
#     137     if not vspace(ans).size == 1:
#     138         raise TypeError(
#     139             "Grad only applies to real scalar-output functions. "
#     140             "Try jacobian, elementwise_grad or holomorphic_grad."
#     141         )
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/autograd/core.py:10, in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/autograd/tracer.py:10, in trace(start_node, fun, x)
#       8 with trace_stack.new_trace() as t:
#       9     start_box = new_box(x, t, start_node)
# ---> 10     end_box = fun(start_box)
#      11     if isbox(end_box) and end_box._trace == start_box._trace:
#      12         return end_box._value, end_box._node
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/autograd/wrap_util.py:15, in unary_to_nary.<locals>.nary_operator.<locals>.nary_f.<locals>.unary_f(x)
#      13 else:
#      14     subargs = subvals(args, zip(argnum, x))
# ---> 15 return fun(*subargs, **kwargs)
#
# Cell In[58], line 72, in approximation_ratio.<locals>.cost_function(p)
#      71 def cost_function(p):
# ---> 72     output_probs = qaoa_circuit(np.repeat(p, qaoa_depth, axis=0), noise_param)
#      73     return output_probs
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/qnode.py:867, in QNode.__call__(self, *args, **kwargs)
#     865     self.execute_kwargs.pop("mode")
#     866 # pylint: disable=unexpected-keyword-arg
# --> 867 res = qml.execute(
#     868     [self.tape],
#     869     device=self.device,
#     870     gradient_fn=self.gradient_fn,
#     871     interface=self.interface,
#     872     gradient_kwargs=self.gradient_kwargs,
#     873     override_shots=override_shots,
#     874     **self.execute_kwargs,
#     875 )
#     877 res = res[0]
#     879 if old_interface == "auto":
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/interfaces/execution.py:407, in execute(tapes, device, gradient_fn, interface, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform)
#     403     return batch_fn(res)
#     405 if gradient_fn == "backprop" or interface is None:
#     406     return batch_fn(
# --> 407         qml.interfaces.cache_execute(
#     408             batch_execute, cache, return_tuple=False, expand_fn=expand_fn
#     409         )(tapes)
#     410     )
#     412 # the default execution function is batch_execute
#     413 execute_fn = qml.interfaces.cache_execute(batch_execute, cache, expand_fn=expand_fn)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/interfaces/execution.py:204, in cache_execute.<locals>.wrapper(tapes, **kwargs)
#     200         return (res, []) if return_tuple else res
#     202 else:
#     203     # execute all unique tapes that do not exist in the cache
# --> 204     res = fn(execution_tapes.values(), **kwargs)
#     206 final_res = []
#     208 for i, tape in enumerate(tapes):
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/interfaces/execution.py:130, in cache_execute.<locals>.fn(tapes, **kwargs)
#     128 def fn(tapes: Sequence[QuantumTape], **kwargs):  # pylint: disable=function-redefined
#     129     tapes = [expand_fn(tape) for tape in tapes]
# --> 130     return original_fn(tapes, **kwargs)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/_qubit_device.py:588, in QubitDevice.batch_execute(self, circuits)
#     583 for circuit in circuits:
#     584     # we need to reset the device here, else it will
#     585     # not start the next computation in the zero state
#     586     self.reset()
# --> 588     res = self.execute(circuit)
#     589     results.append(res)
#     591 if self.tracker.active:
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/devices/default_mixed.py:659, in DefaultMixed.execute(self, circuit, **kwargs)
#     657         wires_list.append(m.wires)
#     658     self.measured_wires = qml.wires.Wires.all_wires(wires_list)
# --> 659 return super().execute(circuit, **kwargs)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/_qubit_device.py:318, in QubitDevice.execute(self, circuit, **kwargs)
#     315 self.check_validity(circuit.operations, circuit.observables)
#     317 # apply all circuit operations
# --> 318 self.apply(circuit.operations, rotations=self._get_diagonalizing_gates(circuit), **kwargs)
#     320 # generate computational basis samples
#     321 if self.shots is not None or circuit.is_sampled:
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/devices/default_mixed.py:727, in DefaultMixed.apply(self, operations, rotations, **kwargs)
#     721         raise DeviceError(
#     722             f"Operation {operation.name} cannot be used after other Operations have already been applied "
#     723             f"on a {self.short_name} device."
#     724         )
#     726 for operation in operations:
# --> 727     self._apply_operation(operation)
#     729 # store the pre-rotated state
#     730 self._pre_rotated_state = self._state
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/devices/default_mixed.py:591, in DefaultMixed._apply_operation(self, operation)
#     588             self._debugger.snapshots[len(self._debugger.snapshots)] = density_matrix
#     589     return
# --> 591 matrices = self._get_kraus(operation)
#     593 if operation in diagonal_in_z_basis:
#     594     self._apply_diagonal_unitary(matrices, wires)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/devices/default_mixed.py:277, in DefaultMixed._get_kraus(self, operation)
#     266 """Return the Kraus operators representing the operation.
#     267
#     268 Args:
#    (...)
#     274     unitary, returns a 1D array representing the matrix diagonal.
#     275 """
#     276 if operation in diagonal_in_z_basis:
# --> 277     return operation.eigvals()
#     279 if isinstance(operation, Channel):
#     280     return operation.kraus_matrices()
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/operation.py:845, in Operator.eigvals(self)
#     820 r"""Eigenvalues of the operator in the computational basis.
#     821
#     822 If :attr:`diagonalizing_gates` are specified and implement a unitary :math:`U^{\dagger}`, the operator
#    (...)
#     841     tensor_like: eigenvalues
#     842 """
#     844 try:
# --> 845     return self.compute_eigvals(*self.parameters, **self.hyperparameters)
#     846 except EigvalsUndefinedError as e:
#     847     # By default, compute the eigenvalues from the matrix representation if one is defined.
#     848     if self.has_matrix:  # pylint: disable=using-constant-test
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/ops/qubit/parametric_ops_single_qubit.py:341, in RZ.compute_eigvals(theta)
#     339 prefactors = qml.math.array([-0.5j, 0.5j], like=theta)
#     340 if qml.math.ndim(theta) == 0:
# --> 341     product = theta * prefactors
#     342 else:
#     343     product = qml.math.outer(theta, prefactors)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/autograd/numpy/numpy_boxes.py:27, in ArrayBox.__mul__(self, other)
# ---> 27 def __mul__(self, other): return anp.multiply(self, other)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/autograd/tracer.py:44, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      42 parents = tuple(box._node for _     , box in boxed_args)
#      43 argnums = tuple(argnum    for argnum, _   in boxed_args)
# ---> 44 ans = f_wrapped(*argvals, **kwargs)
#      45 node = node_constructor(ans, f_wrapped, argvals, kwargs, argnums, parents)
#      46 return new_box(ans, trace, node)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/autograd/tracer.py:48, in primitive.<locals>.f_wrapped(*args, **kwargs)
#      46     return new_box(ans, trace, node)
#      47 else:
# ---> 48     return f_raw(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/QCML/lib/python3.9/site-packages/pennylane/numpy/tensor.py:177, in tensor.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#     174 # Iterate through the ufunc outputs and convert each to a PennyLane tensor.
#     175 # We also correctly set the requires_grad attribute.
#     176 for i in range(len(ufunc_output)):  # pylint: disable=consider-using-enumerate
# --> 177     ufunc_output[i] = tensor(ufunc_output[i], requires_grad=requires_grad)
#     179 if len(ufunc_output) == 1:
#     180     # the ufunc has a single output so return a single tensor
#     181     return ufunc_output[0]
#
# KeyboardInterrupt:

# %%
features = np.array([0.1, 0.2], requires_grad=True)
features
# Out:
# tensor([0.1, 0.2], requires_grad=True)

# %%
# passed 1 teest

edges = [(0, 1), (1, 2), (2, 0), (2, 3)]
num_wires = 4

# We define the Hamiltonian for you!

ops = [qml.PauliZ(0), qml.PauliZ(1),qml.PauliZ(2), qml.PauliZ(3), qml.PauliZ(0)@qml.PauliZ(1), qml.PauliZ(0)@qml.PauliZ(2),qml.PauliZ(1)@qml.PauliZ(2),qml.PauliZ(2)@qml.PauliZ(3)]
coeffs = [0.5, 0.5, 1.25, -0.25, 0.75, 0.75, 0.75, 0.75]

cost_hamiltonian = qml.Hamiltonian(coeffs, ops)

# Write any helper functions you need here
true_value = np.min(np.linalg.eigvalsh(cost_hamiltonian.sparse_matrix().todense()))

dev = qml.device('default.mixed', wires = num_wires)

@qml.qnode(dev) 
def qaoa_circuit(params, noise_param):

    """
    Define the noisy QAOA circuit with only CNOT and rotation gates, with Depolarizing noise
    in the target qubit of each CNOT gate.

    Args:
        params(list(list(float))): A list with length equal to the QAOA depth. Each element is a list that contains 
        the two QAOA parameters of each layer.
        noise_param (float): The noise parameter associated with the depolarization gate

    Returns: 
        (np.tensor): A numpy tensor of 1 element corresponding to the expectation value of the cost Hamiltonian
    
    """

    for i in range(num_wires):
        qml.RY(np.pi/2, i)
        # qml.Hadamard(i)
    for param in params: 
        gamma, alpha = param 

        qml.RZ(2*gamma*0.5, wires=0)
        qml.RZ(2*gamma*0.5, wires=1)
        qml.RZ(2*gamma*1.25, wires=2)
        qml.RZ(2*gamma*-0.25, wires=3)

        qml.CNOT(wires=[0,1])
        qml.DepolarizingChannel(noise_param, wires=1)
        qml.RZ(2*gamma*0.75, 1)
        qml.CNOT(wires=[0,1])
        qml.DepolarizingChannel(noise_param, wires=1)

        qml.CNOT(wires=[0,2])
        qml.DepolarizingChannel(noise_param, wires=2)
        qml.RZ(2*gamma*0.75, 2)
        qml.CNOT(wires=[0,2])
        qml.DepolarizingChannel(noise_param, wires=2)

        qml.CNOT(wires=[1,2])
        qml.DepolarizingChannel(noise_param, wires=2)
        qml.RZ(2*gamma*0.75, 2)
        qml.CNOT(wires=[1,2])    
        qml.DepolarizingChannel(noise_param, wires=2)

        qml.CNOT(wires=[2,3])
        qml.DepolarizingChannel(noise_param, wires=3)
        qml.RZ(2*gamma*0.75, 3)
        qml.CNOT(wires=[2,3])                    
        qml.DepolarizingChannel(noise_param, wires=3)

        for i in range(num_wires):
            qml.RX(2*alpha, wires=i)      
            
        return qml.expval(cost_hamiltonian)
def approximation_ratio(qaoa_depth, noise_param):
    """
    Returns the approximation ratio of the QAOA algorithm for the Minimum Vertex Cover of the given graph
    with depolarizing gates after each native CNOT gate

    Args:
        qaoa_depth (float): The number of cost/mixer layer in the QAOA algorithm used
        noise_param (float): The noise parameter associated with the depolarization gate
    
    Returns: 
        (float): The approximation ratio for the noisy QAOA
    """

    print ("approximation_ratio : ", qaoa_depth, noise_param)
    params = np.random.uniform(0, 2*np.pi, (qaoa_depth, 2))

    def cost_function(p):
        return qaoa_circuit(p, noise_param)
    
    opt = qml.AdamOptimizer(stepsize=0.1)

    for it in range(500):
        params, cost = opt.step_and_cost(cost_function, params)
        if it % 50 == 0:
            print (it, " iter, cost = ", cost, cost/true_value)

    minval = cost_function(params)
    return minval/true_value
# These functions are responsible for testing the solution.
random_params = np.array([np.random.rand(2)])

ops_2 = [qml.PauliX(0), qml.PauliX(1), qml.PauliX(2), qml.PauliX(3)]
coeffs_2 = [1,1,1,1]

mixer_hamiltonian = qml.Hamiltonian(coeffs_2, ops_2)

@qml.qnode(dev)
def noiseless_qaoa(params):

    for wire in range(num_wires):

        qml.Hadamard(wires = wire)

    for elem in params:

        qml.ApproxTimeEvolution(cost_hamiltonian, elem[0], 1)
        qml.ApproxTimeEvolution(mixer_hamiltonian, elem[1],1)

    return qml.expval(cost_hamiltonian)

random_params = np.array([np.random.rand(2)])

circuit_check = (np.isclose(noiseless_qaoa(random_params) - qaoa_circuit(random_params,0),0)).numpy()

def run(test_case_input: str) -> str:
    input = json.loads(test_case_input)
    output = approximation_ratio(*input)

    return str(output)

def check(solution_output: str, expected_output: str) -> None:
    solution_output = json.loads(solution_output)
    expected_output = json.loads(expected_output)
    
    tape = qaoa_circuit.qtape
    names = [op.name for op in tape.operations]
    random_params = np.array([np.random.rand(2)])

    assert circuit_check, "qaoa_circuit is not doing what it's expected to."

    assert names.count('ApproxTimeEvolution') == 0, "Your circuit must not use the built-in PennyLane Trotterization."
     
    assert set(names) == {'DepolarizingChannel', 'RX', 'RY', 'RZ', 'CNOT'}, "Your circuit must use qml.RX, qml.RY, qml.RZ, qml.CNOT, and qml.DepolarizingChannel."

    assert solution_output > expected_output - 0.02

# These are the public test cases
test_cases = [
    ('[1, 0.003]', '0.1307'),
    ('[2,0.005]', '0.4875'),
]

# This will run the public test cases locally
for i, (input_, expected_output) in enumerate(test_cases):
    print(f"Running test case {i} with input '{input_}'...")

    try:
        output = run(input_)

    except Exception as exc:
        print(f"Runtime Error. {exc}")

    else:
        if message := check(output, expected_output):
            print(f"Wrong Answer. Have: '{output}'. Want: '{expected_output}'.")

        else:
            print("Correct!")
# Out:
# Running test case 0 with input '[1, 0.003]'...
# approximation_ratio :  1 0.003
# 0  iter, cost =  -0.1150105740655393 0.038336858021846436
# 50  iter, cost =  -0.39119404791244666 0.13039801597081555
# 100  iter, cost =  -0.3920527933504877 0.13068426445016257
# 150  iter, cost =  -0.39205784454789205 0.13068594818263068
# 200  iter, cost =  -0.3920578650105109 0.13068595500350363
# 250  iter, cost =  -0.39205786517202706 0.13068595505734235
# 300  iter, cost =  -0.39205786517352686 0.13068595505784228
# 350  iter, cost =  -0.3920578651735358 0.13068595505784528
# 400  iter, cost =  -0.3920578651735358 0.13068595505784528
# 450  iter, cost =  -0.3920578651735356 0.1306859550578452
# Correct!
# Running test case 1 with input '[2,0.005]'...
# approximation_ratio :  2 0.005
# 0  iter, cost =  0.30233483737013844 -0.10077827912337949
# 50  iter, cost =  -0.3871767850573692 0.1290589283524564
# 100  iter, cost =  -0.3893966616422878 0.12979888721409594
# 150  iter, cost =  -0.389403363485609 0.12980112116186968
# 200  iter, cost =  -0.38940339562370047 0.12980113187456682
# 250  iter, cost =  -0.38940339605919877 0.12980113201973292
# 300  iter, cost =  -0.38940339606327146 0.12980113202109048
# 350  iter, cost =  -0.3894033960632876 0.12980113202109586
# 400  iter, cost =  -0.38940339606328667 0.12980113202109556
# 450  iter, cost =  -0.38940339606328683 0.1298011320210956
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[61], line 168
#     165     print(f"Runtime Error. {exc}")
#     167 else:
# --> 168     if message := check(output, expected_output):
#     169         print(f"Wrong Answer. Have: '{output}'. Want: '{expected_output}'.")
#     171     else:
#
# Cell In[61], line 149, in check(solution_output, expected_output)
#     145 assert names.count('ApproxTimeEvolution') == 0, "Your circuit must not use the built-in PennyLane Trotterization."
#     147 assert set(names) == {'DepolarizingChannel', 'RX', 'RY', 'RZ', 'CNOT'}, "Your circuit must use qml.RX, qml.RY, qml.RZ, qml.CNOT, and qml.DepolarizingChannel."
# --> 149 assert solution_output > expected_output - 0.02
#
# AssertionError:
