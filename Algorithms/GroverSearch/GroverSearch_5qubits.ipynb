# %% [markdown]
# Amplitude Amplification

# %%
from qiskit import *
import numpy as np
from qiskit.visualization import plot_state_city, plot_bloch_multivector, plot_histogram
from qiskit.quantum_info.operators import Operator, Pauli
from qiskit import IBMQ, Aer, transpile, execute
from scipy.fft import fft
from math import pi
from qiskit.quantum_info import Statevector
from IPython.display import display, Latex
from qiskit.circuit.library import QFT

# %%
no_of_qubits = 6
no_of_search_space = 2**no_of_qubits

oracle = QuantumCircuit(no_of_qubits, name="oracle")

for i in range(no_of_qubits-1): 
    oracle.cz(i,no_of_qubits-1)

oracle.to_gate()

oracle.draw(output="mpl")

# %%
OracleTest = QuantumCircuit(no_of_qubits, name="OracleTest")
OracleTest.h(range(no_of_qubits))
OracleTest.append(oracle, range(no_of_qubits))
from IPython.display import Latex
from qiskit.visualization import state_visualization
state = Statevector(OracleTest)
print (state)
state.draw(output="latex", )

prefix = "$$\\begin{align}"
suffix = "\\end{align}$$"
state_to_latex = state_visualization._state_to_latex_ket(state.data, max_size = 128)

Latex(prefix + state_to_latex + suffix)
# Out:
# Statevector([ 0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#               0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#               0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#               0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#               0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#               0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,  0.125+0.j,
#               0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,
#               0.125+0.j, -0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,
#              -0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,
#              -0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j,  0.125+0.j,
#               0.125+0.j, -0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,
#               0.125+0.j,  0.125+0.j, -0.125+0.j, -0.125+0.j,  0.125+0.j,
#              -0.125+0.j,  0.125+0.j,  0.125+0.j, -0.125+0.j],
#             dims=(2, 2, 2, 2, 2, 2))
# $$\begin{align}\frac{1}{8} |000000\rangle+\frac{1}{8} |000001\rangle+\frac{1}{8} |000010\rangle+\frac{1}{8} |000011\rangle+\frac{1}{8} |000100\rangle+\frac{1}{8} |000101\rangle+\frac{1}{8} |000110\rangle+\frac{1}{8} |000111\rangle+\frac{1}{8} |001000\rangle+\frac{1}{8} |001001\rangle+\frac{1}{8} |001010\rangle+\frac{1}{8} |001011\rangle+\frac{1}{8} |001100\rangle+\frac{1}{8} |001101\rangle+\frac{1}{8} |001110\rangle+\frac{1}{8} |001111\rangle+\frac{1}{8} |010000\rangle+\frac{1}{8} |010001\rangle+\frac{1}{8} |010010\rangle+\frac{1}{8} |010011\rangle+\frac{1}{8} |010100\rangle+\frac{1}{8} |010101\rangle+\frac{1}{8} |010110\rangle+\frac{1}{8} |010111\rangle+\frac{1}{8} |011000\rangle+\frac{1}{8} |011001\rangle+\frac{1}{8} |011010\rangle+\frac{1}{8} |011011\rangle+\frac{1}{8} |011100\rangle+\frac{1}{8} |011101\rangle+\frac{1}{8} |011110\rangle+\frac{1}{8} |011111\rangle+\frac{1}{8} |100000\rangle- \frac{1}{8} |100001\rangle- \frac{1}{8} |100010\rangle+\frac{1}{8} |100011\rangle- \frac{1}{8} |100100\rangle+\frac{1}{8} |100101\rangle+\frac{1}{8} |100110\rangle- \frac{1}{8} |100111\rangle- \frac{1}{8} |101000\rangle+\frac{1}{8} |101001\rangle+\frac{1}{8} |101010\rangle- \frac{1}{8} |101011\rangle+\frac{1}{8} |101100\rangle- \frac{1}{8} |101101\rangle- \frac{1}{8} |101110\rangle+\frac{1}{8} |101111\rangle- \frac{1}{8} |110000\rangle+\frac{1}{8} |110001\rangle+\frac{1}{8} |110010\rangle- \frac{1}{8} |110011\rangle+\frac{1}{8} |110100\rangle- \frac{1}{8} |110101\rangle- \frac{1}{8} |110110\rangle+\frac{1}{8} |110111\rangle+\frac{1}{8} |111000\rangle- \frac{1}{8} |111001\rangle- \frac{1}{8} |111010\rangle+\frac{1}{8} |111011\rangle- \frac{1}{8} |111100\rangle+\frac{1}{8} |111101\rangle+\frac{1}{8} |111110\rangle- \frac{1}{8} |111111\rangle\end{align}$$

# %%
import operator
from qiskit import *
from qiskit.quantum_info.operators import Operator, Pauli
import math
from qiskit.circuit.library import ZGate

qreg = QuantumRegister(no_of_qubits)
creg = ClassicalRegister(no_of_qubits)
q = QuantumCircuit(qreg)

for i in range(no_of_qubits):
    q.h(i)

for i in range(int(2*math.sqrt(no_of_qubits))):
    q.append(oracle,range(no_of_qubits))

    cozgate = ZGate().control(no_of_qubits-1)

    for i  in range(1):
        q.h(range(no_of_qubits))
        q.x(range(no_of_qubits))

    q.append(cozgate, qreg)

    for i  in range(1):
        q.x(range(no_of_qubits))
        q.h(range(no_of_qubits))
        
q.draw(output="mpl", scale=0.5, fold=1000)

# %%
backend = Aer.get_backend('aer_simulator')  # Tell Qiskit how to simulate our circuit

q.save_statevector()   # Tell simulator to save statevector
result = backend.run(transpile(q, backend), shots=1000).result()
out_state = result.get_statevector()
np.around(out_state, 2)
print(out_state) # Display the output state vector
plot_histogram(result.get_counts(), figsize=(12,8))
# Out:
# Statevector([ 1.37383090e-16+7.65404249e-18j,
#               5.55111512e-17-7.65404249e-18j,
#               1.38777878e-16-7.65404249e-18j,
#               7.85046229e-17+7.65404249e-18j,
#               1.38777878e-16-7.65404249e-18j,
#               6.86915451e-17+7.65404249e-18j,
#               1.57009246e-16+7.65404249e-18j,
#               0.00000000e+00-7.65404249e-18j,
#               6.93889390e-17-7.65404249e-18j,
#              -9.81307787e-18+7.65404249e-18j,
#               7.85046229e-17+7.65404249e-18j,
#               0.00000000e+00-7.65404249e-18j,
#               9.81307787e-17+7.65404249e-18j,
#               5.55111512e-17-7.65404249e-18j,
#               5.55111512e-17-7.65404249e-18j,
#              -8.83177008e-17+7.65404249e-18j,
#               5.55111512e-17-7.65404249e-18j,
#               3.92523115e-17+7.65404249e-18j,
#               4.90653893e-17+7.65404249e-18j,
#              -1.38777878e-17-7.65404249e-18j,
#               1.96261557e-17+7.65404249e-18j,
#               0.00000000e+00-7.65404249e-18j,
#               2.77555756e-17-7.65404249e-18j,
#              -6.86915451e-17+7.65404249e-18j,
#               8.83177008e-17+7.65404249e-18j,
#               4.16333634e-17-7.65404249e-18j,
#               2.77555756e-17-7.65404249e-18j,
#              -8.83177008e-17+7.65404249e-18j,
#               5.55111512e-17-7.65404249e-18j,
#              -1.96261557e-17+7.65404249e-18j,
#               4.90653893e-17+7.65404249e-18j,
#              -8.32667268e-17-7.65404249e-18j,
#               1.17756934e-16-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#              -2.50000000e-01-8.03674462e-16j,
#              -5.88784672e-17-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#               2.94392336e-17-6.88863825e-17j,
#               5.88784672e-17-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#              -2.50000000e-01-8.03674462e-16j,
#               9.81307787e-18-6.88863825e-17j,
#               1.96261557e-17-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#              -3.92523115e-17-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#              -2.50000000e-01-8.03674462e-16j,
#              -1.07943857e-16-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#               1.54074396e-32-6.88863825e-17j,
#               6.86915451e-17-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#               5.88784672e-17-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#              -2.50000000e-01-8.03674462e-16j,
#              -2.94392336e-17-6.88863825e-17j,
#               1.07943857e-16-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#              -2.50000000e-01-8.03674462e-16j,
#               4.90653893e-17-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j,
#               3.92523115e-17-6.88863825e-17j,
#              -9.81307787e-18-6.88863825e-17j,
#              -2.50000000e-01-8.03674462e-16j],
#             dims=(2, 2, 2, 2, 2, 2))

# %%
import math
math.ceil(pi*math.sqrt(2**no_of_qubits)/4)
# Out:
# 7
