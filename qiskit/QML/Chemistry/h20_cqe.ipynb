# %% [markdown]
# Find the ground state of water molecule H2O
#
# Steps involved are as below.
# - Create electronic structure problem for the water molecule.
# - Convert the problem to second quantization format using anhilisation and creation operators for each molecular orbit.
# - Convert Fermionic op to qubit hamiltonian

# %%
from qiskit.quantum_info import SparsePauliOp
from qiskit import *
from qiskit.algorithms.minimum_eigensolvers import VQE 
from qiskit.algorithms.optimizers import SLSQP 
from qiskit.circuit.library import TwoLocal 
from qiskit.quantum_info import SparsePauliOp 
from qiskit.primitives import Estimator 
import numpy as np 
from qiskit_nature.units import DistanceUnit
from qiskit_nature import settings
from qiskit_nature.second_q.circuit.library import HartreeFock, UCCSD
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.operators import FermionicOp
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_nature.second_q.mappers import ParityMapper
from qiskit_nature.second_q.transformers import ActiveSpaceTransformer

settings.tensor_unwrapping = False
settings.use_pauli_sum_op = False

# %% [markdown]
# - Create electronic structure problem ffor the water molecule.

# %%
driver = PySCFDriver(atom='O 0.0 0.0 0.0; H 0.757 0.586 0.0; H -0.757 0.586 0.0', unit=DistanceUnit.ANGSTROM, charge=0, spin=0, basis='sto3g')
electronic_structure_problem = driver.run()

print('Electonic structue problem (Molecule) ')
print(electronic_structure_problem.molecule)
print('(Basis) = ', electronic_structure_problem.basis)
print('(num_spatial_orbitals) = ', electronic_structure_problem.num_spatial_orbitals)
# Out:
# Electonic structue problem (Molecule)
# Molecule:
# 	Multiplicity: 1
# 	Charge: 0
# 	Unit: Bohr
# 	Geometry:
# 		O	(0.0, 0.0, 0.0)
# 		H	(1.430522676295752, 1.1073795089951262, 0.0)
# 		H	(-1.430522676295752, 1.1073795089951262, 0.0)
# 	Masses:
# 		O	16
# 		H	1
# 		H	1
# (Basis) =  ElectronicBasis.MO
# (num_spatial_orbitals) =  7

# %% [markdown]
# - Convert the problem to second quantization format using anhilisation and creation operators for each molecular orbit.

# %%
FermionicOpWithCoefficients = electronic_structure_problem.hamiltonian.second_q_op()
print("Number of spin orbitals:", FermionicOpWithCoefficients.num_spin_orbitals)
# Out:
# 14 Fermionic Operator
# number spin orbitals=14, number terms=3150
#   -32.703135955376844 * ( +_0 -_0 )
# + 0.5580936712152312 * ( +_0 -_1 )
# + -0.2352094242778738 * ( +_0 -_3 )
# + 0.3048033604768665 * ( +_0 -_5 )
# + 0.5580936712152322 * ( +_1 -_0 )
# + -7.671205435641992 * ( +_1 -_1 )
# + 0.43122992377249414 * ( +_1 -_3 )
# + -1.3818822921338914 * ( +_1 -_5 )
# + -6.365144017120206 * ( +_2 -_2 )
# + -1.7098558272478181 * ( +_2 -_6 )
# + -0.23520942427787492 * ( +_3 -_0 )
# + 0.431229923772494 * ( +_3 -_1 )
# + -6.987578559770135 * ( +_3 -_3 )
# + -1.0792894461946567 * ( +_3 -_5 )
# + -7.457567275062586 * ( +_4 -_4 )
# + 0.30480336047686735 * ( +_5 -_0 )
# + -1.3818822921338925 * ( +_5 -_1 )
# + -1.0792894461946558 * ( +_5 -_3 )
# + -5.335829926705099 * ( +_5 -_5 )
# + -1.7098558272478186 * ( +_6 -_2 )
# + -5.603866530889234 * ( +_6 -_6 )
# + -32.703135955376844 * ( +_7 -_7 )
# + 0.5580936712152312 * ( +_7 -_8 )
# + -0.2352094242778738 * ( +_7 -_10 )
# + 0.3048033604768665 * ( +_7 -_12 )
# + 0.5580936712152322 * ( +_8 -_7 )
# + -7.671205435641992 * ( +_8 -_8 )
# + 0.43122992377249414 * ( +_8 -_10 )
# + -1.3818822921338914 * ( +_8 -_12 )
# + -6.365144017120206 * ( +_9 -_9 )
# + -1.7098558272478181 * ( +_9 -_13 )
# + -0.23520942427787492 * ( +_10 -_7 )
# + 0.431229923772494 * ( +_10 -_8 )
# + -6.987578559770135 * ( +_10 -_10 )
# + -1.0792894461946567 * ( +_10 -_12 )
# + -7.457567275062586 * ( +_11 -_11 )
# + 0.30480336047686735 * ( +_12 -_7 )
# + -1.3818822921338925 * ( +_12 -_8 )
# + -1.0792894461946558 * ( +_12 -_10 )
# + -5.335829926705099 * ( +_12 -_12 )
# + -1.7098558272478186 * ( +_13 -_9 )
# + -5.603866530889234 * ( +_13 -_13 )
# + 2.372248352384161 * ( +_0 +_0 -_0 -_0 )
# + -0.20831409786744726 * ( +_0 +_0 -_0 -_1 )
# + 0.09180183646543422 * ( +_0 +_0 -_0 -_3 )
# + -0.11905746595391381 * ( +_0 +_0 -_0 -_5 )
# + -0.2083140978674472 * ( +_0 +_0 -_1 -_0 )
# + 0.029085068113943183 * ( +_0 +_0 -_1 -_1 )
# + -0.011246735293008937 * ( +_0 +_0 -_1 -_3 )
# + 0.01790790933556573 * ( +_0 +_0 -_1 -_5 )
# + 0.005497597716048515 * ( +_0 +_0 -_2 -_2 )
# + 0.007659485869533509 * ( +_0 +_0 -_2 -_6 )
# + 0.09180183646543424 * ( +_0 +_0 -_3 -_0 )
# + -0.01124673529300895 * ( +_0 +_0 -_3 -_1 )
# + 0.013891105891393706 * ( +_0 +_0 -_3 -_3 )
# + -0.0002864078952772589 * ( +_0 +_0 -_3 -_5 )
# + 0.013022424695686034 * ( +_0 +_0 -_4 -_4 )
# + -0.1190574659539139 * ( +_0 +_0 -_5 -_0 )
# + 0.01790790933556575 * ( +_0 +_0 -_5 -_1 )
# + -0.0002864078952772633 * ( +_0 +_0 -_5 -_3 )
# + 0.015663088681203644 * ( +_0 +_0 -_5 -_5 )
# + 0.007659485869533511 * ( +_0 +_0 -_6 -_2 )
# + 0.01070038285344596 * ( +_0 +_0 -_6 -_6 )
# + -0.20831409786744703 * ( +_0 +_1 -_0 -_0 )
# + 0.02908506811394318 * ( +_0 +_1 -_0 -_1 )
# + -0.011246735293008946 * ( +_0 +_1 -_0 -_3 )
# + 0.017907909335565735 * ( +_0 +_1 -_0 -_5 )
# + 0.5022752592313258 * ( +_0 +_1 -_1 -_0 )
# + -0.006483470692832983 * ( +_0 +_1 -_1 -_1 )
# + 0.008030511829813203 * ( +_0 +_1 -_1 -_3 )
# + -0.00039156406691046454 * ( +_0 +_1 -_1 -_5 )
# + 0.00888408063083779 * ( +_0 +_1 -_2 -_2 )
# + 0.011554962723641276 * ( +_0 +_1 -_2 -_6 )
# + -0.06417601902559858 * ( +_0 +_1 -_3 -_0 )
# + 0.004607064469537401 * ( +_0 +_1 -_3 -_1 )
# + 0.009464004473381282 * ( +_0 +_1 -_3 -_3 )
# + 0.010170080326596605 * ( +_0 +_1 -_3 -_5 )
# + 0.016230157660897734 * ( +_0 +_1 -_4 -_4 )
# + 0.15421006433785514 * ( +_0 +_1 -_5 -_0 )
# + -0.00332480810650721 * ( +_0 +_1 -_5 -_1 )
# + 0.009325359416068662 * ( +_0 +_1 -_5 -_3 )
# + 0.0033977498864339634 * ( +_0 +_1 -_5 -_5 )
# + 0.006937845359291025 * ( +_0 +_1 -_6 -_2 )
# + 0.009153660346168524 * ( +_0 +_1 -_6 -_6 )
# + 0.005497597716048515 * ( +_0 +_2 -_0 -_2 )
# + 0.00765948586953351 * ( +_0 +_2 -_0 -_6 )
# + 0.00888408063083779 * ( +_0 +_2 -_1 -_2 )
# + 0.011554962723641277 * ( +_0 +_2 -_1 -_6 )
# + 0.4000220740267712 * ( +_0 +_2 -_2 -_0 )
# + -0.002202812656562158 * ( +_0 +_2 -_2 -_1 )
# + 0.003235298548729154 * ( +_0 +_2 -_2 -_3 )
# + 9.85002633389265e-05 * ( +_0 +_2 -_2 -_5 )
# + -0.0017204315837104638 * ( +_0 +_2 -_3 -_2 )
# + -0.002481213223072591 * ( +_0 +_2 -_3 -_6 )
# + 0.0015748818522589036 * ( +_0 +_2 -_5 -_2 )
# + 0.0019322820936806145 * ( +_0 +_2 -_5 -_6 )
# + 0.1812009390814194 * ( +_0 +_2 -_6 -_0 )
# + -0.003752765939143082 * ( +_0 +_2 -_6 -_1 )
# + -0.0004129409973066059 * ( +_0 +_2 -_6 -_3 )
# + -0.003494983782990655 * ( +_0 +_2 -_6 -_5 )
# + 0.09180183646543413 * ( +_0 +_3 -_0 -_0 )
# + -0.01124673529300895 * ( +_0 +_3 -_0 -_1 )
# + 0.01389110589139371 * ( +_0 +_3 -_0 -_3 )
# + -0.0002864078952772563 * ( +_0 +_3 -_0 -_5 )
# + -0.06417601902559865 * ( +_0 +_3 -_1 -_0 )
# + 0.0046070644695374125 * ( +_0 +_3 -_1 -_1 )
# + 0.009464004473381278 * ( +_0 +_3 -_1 -_3 )
# + 0.01017008032659661 * ( +_0 +_3 -_1 -_5 )
# + -0.0017204315837104636 * ( +_0 +_3 -_2 -_2 )
# + -0.0024812132230725924 * ( +_0 +_3 -_2 -_6 )
# + 0.5000018268716416 * ( +_0 +_3 -_3 -_0 )
# + -0.006786020207397403 * ( +_0 +_3 -_3 -_1 )
# + -0.0056861089411045125 * ( +_0 +_3 -_3 -_3 )
# + -0.009621901749820565 * ( +_0 +_3 -_3 -_5 )
# + -0.006725730203450187 * ( +_0 +_3 -_4 -_4 )
# + 0.10960665820998367 * ( +_0 +_3 -_5 -_0 )
# + -0.0011145251113429645 * ( +_0 +_3 -_5 -_1 )
# + 0.0011744439184291006 * ( +_0 +_3 -_5 -_3 )
# + -0.00013734154277086953 * ( +_0 +_3 -_5 -_5 )
# + -0.004818402181974993 * ( +_0 +_3 -_6 -_2 )
# + -0.006602180403890646 * ( +_0 +_3 -_6 -_6 )
# + 0.013022424695686034 * ( +_0 +_4 -_0 -_4 )
# + 0.016230157660897738 * ( +_0 +_4 -_1 -_4 )
# + -0.0067257302034501865 * ( +_0 +_4 -_3 -_4 )
# + 0.557668095182032 * ( +_0 +_4 -_4 -_0 )
# + -0.005846666275339695 * ( +_0 +_4 -_4 -_1 )
# + 0.002559124049433059 * ( +_0 +_4 -_4 -_3 )
# + -0.003105685015072045 * ( +_0 +_4 -_4 -_5 )
# + 0.007878382769591146 * ( +_0 +_4 -_5 -_4 )
# + -0.11905746595391371 * ( +_0 +_5 -_0 -_0 )
# + 0.01790790933556574 * ( +_0 +_5 -_0 -_1 )
# + -0.0002864078952772657 * ( +_0 +_5 -_0 -_3 )
# + 0.015663088681203637 * ( +_0 +_5 -_0 -_5 )
# + 0.15421006433785522 * ( +_0 +_5 -_1 -_0 )
# + -0.0033248081065072274 * ( +_0 +_5 -_1 -_1 )
# + 0.009325359416068667 * ( +_0 +_5 -_1 -_3 )
# + 0.003397749886433953 * ( +_0 +_5 -_1 -_5 )
# + 0.0015748818522589036 * ( +_0 +_5 -_2 -_2 )
# + 0.0019322820936806145 * ( +_0 +_5 -_2 -_6 )
# + 0.10960665820998369 * ( +_0 +_5 -_3 -_0 )
# + -0.0011145251113429517 * ( +_0 +_5 -_3 -_1 )
# + 0.001174443918429097 * ( +_0 +_5 -_3 -_3 )
# + -0.00013734154277085942 * ( +_0 +_5 -_3 -_5 )
# + 0.007878382769591144 * ( +_0 +_5 -_4 -_4 )
# + 0.4013473970427439 * ( +_0 +_5 -_5 -_0 )
# + -0.0034885677001654436 * ( +_0 +_5 -_5 -_1 )
# + 0.010599008579304013 * ( +_0 +_5 -_5 -_3 )
# + 0.004201261578125791 * ( +_0 +_5 -_5 -_5 )
# + 0.004607388980076465 * ( +_0 +_5 -_6 -_2 )
# + 0.006100835170006294 * ( +_0 +_5 -_6 -_6 )
# + 0.007659485869533512 * ( +_0 +_6 -_0 -_2 )
# + 0.010700382853445958 * ( +_0 +_6 -_0 -_6 )
# + 0.006937845359291027 * ( +_0 +_6 -_1 -_2 )
# + 0.009153660346168518 * ( +_0 +_6 -_1 -_6 )
# + 0.18120093908141943 * ( +_0 +_6 -_2 -_0 )
# + -0.0037527659391431 * ( +_0 +_6 -_2 -_1 )
# + -0.00041294099730659976 * ( +_0 +_6 -_2 -_3 )
# + -0.003494983782990666 * ( +_0 +_6 -_2 -_5 )
# + -0.004818402181974994 * ( +_0 +_6 -_3 -_2 )
# + -0.006602180403890642 * ( +_0 +_6 -_3 -_6 )
# + 0.0046073889800764736 * ( +_0 +_6 -_5 -_2 )
# + 0.0061008351700062805 * ( +_0 +_6 -_5 -_6 )
# + 0.4345426355843152 * ( +_0 +_6 -_6 -_0 )
# + -0.00470159832236389 * ( +_0 +_6 -_6 -_1 )
# + 0.00208452959213619 * ( +_0 +_6 -_6 -_3 )
# + -0.0025667307360305964 * ( +_0 +_6 -_6 -_5 )
# + 2.372248352384161 * ( +_0 +_7 -_7 -_0 )
# + -0.20831409786744726 * ( +_0 +_7 -_7 -_1 )
# + 0.09180183646543422 * ( +_0 +_7 -_7 -_3 )
# + -0.11905746595391381 * ( +_0 +_7 -_7 -_5 )
# + -0.2083140978674472 * ( +_0 +_7 -_8 -_0 )
# + 0.029085068113943183 * ( +_0 +_7 -_8 -_1 )
# + -0.011246735293008937 * ( +_0 +_7 -_8 -_3 )
# + 0.01790790933556573 * ( +_0 +_7 -_8 -_5 )
# + 0.005497597716048515 * ( +_0 +_7 -_9 -_2 )
# + 0.007659485869533509 * ( +_0 +_7 -_9 -_6 )
# + 0.09180183646543424 * ( +_0 +_7 -_10 -_0 )
# + -0.01124673529300895 * ( +_0 +_7 -_10 -_1 )
# + 0.013891105891393706 * ( +_0 +_7 -_10 -_3 )
# + -0.0002864078952772589 * ( +_0 +_7 -_10 -_5 )
# + 0.013022424695686034 * ( +_0 +_7 -_11 -_4 )
# + -0.1190574659539139 * ( +_0 +_7 -_12 -_0 )
# + 0.01790790933556575 * ( +_0 +_7 -_12 -_1 )
# + -0.0002864078952772633 * ( +_0 +_7 -_12 -_3 )
# + 0.015663088681203644 * ( +_0 +_7 -_12 -_5 )
# + 0.007659485869533511 * ( +_0 +_7 -_13 -_2 )
# + 0.01070038285344596 * ( +_0 +_7 -_13 -_6 )
# + -0.20831409786744703 * ( +_0 +_8 -_7 -_0 )
# + 0.02908506811394318 * ( +_0 +_8 -_7 -_1 )
# + -0.011246735293008946 * ( +_0 +_8 -_7 -_3 )
# + 0.017907909335565735 * ( +_0 +_8 -_7 -_5 )
# + 0.5022752592313258 * ( +_0 +_8 -_8 -_0 )
# + -0.006483470692832983 * ( +_0 +_8 -_8 -_1 )
# + 0.008030511829813203 * ( +_0 +_8 -_8 -_3 )
# + -0.00039156406691046454 * ( +_0 +_8 -_8 -_5 )
# + 0.00888408063083779 * ( +_0 +_8 -_9 -_2 )
# + 0.011554962723641276 * ( +_0 +_8 -_9 -_6 )
# + -0.06417601902559858 * ( +_0 +_8 -_10 -_0 )
# + 0.004607064469537401 * ( +_0 +_8 -_10 -_1 )
# + 0.009464004473381282 * ( +_0 +_8 -_10 -_3 )
# + 0.010170080326596605 * ( +_0 +_8 -_10 -_5 )
# + 0.016230157660897734 * ( +_0 +_8 -_11 -_4 )
# + 0.15421006433785514 * ( +_0 +_8 -_12 -_0 )
# + -0.00332480810650721 * ( +_0 +_8 -_12 -_1 )
# + 0.009325359416068662 * ( +_0 +_8 -_12 -_3 )
# + 0.0033977498864339634 * ( +_0 +_8 -_12 -_5 )
# + 0.006937845359291025 * ( +_0 +_8 -_13 -_2 )
# + 0.009153660346168524 * ( +_0 +_8 -_13 -_6 )
# + 0.005497597716048515 * ( +_0 +_9 -_7 -_2 )
# + 0.00765948586953351 * ( +_0 +_9 -_7 -_6 )
# + 0.00888408063083779 * ( +_0 +_9 -_8 -_2 )
# + 0.011554962723641277 * ( +_0 +_9 -_8 -_6 )
# + 0.4000220740267712 * ( +_0 +_9 -_9 -_0 )
# + -0.002202812656562158 * ( +_0 +_9 -_9 -_1 )
# + 0.003235298548729154 * ( +_0 +_9 -_9 -_3 )
# + 9.85002633389265e-05 * ( +_0 +_9 -_9 -_5 )
# + -0.0017204315837104638 * ( +_0 +_9 -_10 -_2 )
# + -0.002481213223072591 * ( +_0 +_9 -_10 -_6 )
# + 0.0015748818522589036 * ( +_0 +_9 -_12 -_2 )
# + 0.0019322820936806145 * ( +_0 +_9 -_12 -_6 )
# + 0.1812009390814194 * ( +_0 +_9 -_13 -_0 )
# + -0.003752765939143082 * ( +_0 +_9 -_13 -_1 )
# + -0.0004129409973066059 * ( +_0 +_9 -_13 -_3 )
# + -0.003494983782990655 * ( +_0 +_9 -_13 -_5 )
# + 0.09180183646543413 * ( +_0 +_10 -_7 -_0 )
# + -0.01124673529300895 * ( +_0 +_10 -_7 -_1 )
# + 0.01389110589139371 * ( +_0 +_10 -_7 -_3 )
# + -0.0002864078952772563 * ( +_0 +_10 -_7 -_5 )
# + -0.06417601902559865 * ( +_0 +_10 -_8 -_0 )
# + 0.0046070644695374125 * ( +_0 +_10 -_8 -_1 )
# + 0.009464004473381278 * ( +_0 +_10 -_8 -_3 )
# + 0.01017008032659661 * ( +_0 +_10 -_8 -_5 )
# + -0.0017204315837104636 * ( +_0 +_10 -_9 -_2 )
# + -0.0024812132230725924 * ( +_0 +_10 -_9 -_6 )
# + 0.5000018268716416 * ( +_0 +_10 -_10 -_0 )
# + -0.006786020207397403 * ( +_0 +_10 -_10 -_1 )
# + -0.0056861089411045125 * ( +_0 +_10 -_10 -_3 )
# + -0.009621901749820565 * ( +_0 +_10 -_10 -_5 )
# + -0.006725730203450187 * ( +_0 +_10 -_11 -_4 )
# + 0.10960665820998367 * ( +_0 +_10 -_12 -_0 )
# + -0.0011145251113429645 * ( +_0 +_10 -_12 -_1 )
# + 0.0011744439184291006 * ( +_0 +_10 -_12 -_3 )
# + -0.00013734154277086953 * ( +_0 +_10 -_12 -_5 )
# + -0.004818402181974993 * ( +_0 +_10 -_13 -_2 )
# + -0.006602180403890646 * ( +_0 +_10 -_13 -_6 )
# + 0.013022424695686034 * ( +_0 +_11 -_7 -_4 )
# + 0.016230157660897738 * ( +_0 +_11 -_8 -_4 )
# + -0.0067257302034501865 * ( +_0 +_11 -_10 -_4 )
# + 0.557668095182032 * ( +_0 +_11 -_11 -_0 )
# + -0.005846666275339695 * ( +_0 +_11 -_11 -_1 )
# + 0.002559124049433059 * ( +_0 +_11 -_11 -_3 )
# + -0.003105685015072045 * ( +_0 +_11 -_11 -_5 )
# + 0.007878382769591146 * ( +_0 +_11 -_12 -_4 )
# + -0.11905746595391371 * ( +_0 +_12 -_7 -_0 )
# + 0.01790790933556574 * ( +_0 +_12 -_7 -_1 )
# + -0.0002864078952772657 * ( +_0 +_12 -_7 -_3 )
# + 0.015663088681203637 * ( +_0 +_12 -_7 -_5 )
# + 0.15421006433785522 * ( +_0 +_12 -_8 -_0 )
# + -0.0033248081065072274 * ( +_0 +_12 -_8 -_1 )
# + 0.009325359416068667 * ( +_0 +_12 -_8 -_3 )
# + 0.003397749886433953 * ( +_0 +_12 -_8 -_5 )
# + 0.0015748818522589036 * ( +_0 +_12 -_9 -_2 )
# + 0.0019322820936806145 * ( +_0 +_12 -_9 -_6 )
# + 0.10960665820998369 * ( +_0 +_12 -_10 -_0 )
# + -0.0011145251113429517 * ( +_0 +_12 -_10 -_1 )
# + 0.001174443918429097 * ( +_0 +_12 -_10 -_3 )
# + -0.00013734154277085942 * ( +_0 +_12 -_10 -_5 )
# + 0.007878382769591144 * ( +_0 +_12 -_11 -_4 )
# + 0.4013473970427439 * ( +_0 +_12 -_12 -_0 )
# + -0.0034885677001654436 * ( +_0 +_12 -_12 -_1 )
# + 0.010599008579304013 * ( +_0 +_12 -_12 -_3 )
# + 0.004201261578125791 * ( +_0 +_12 -_12 -_5 )
# + 0.004607388980076465 * ( +_0 +_12 -_13 -_2 )
# + 0.006100835170006294 * ( +_0 +_12 -_13 -_6 )
# + 0.007659485869533512 * ( +_0 +_13 -_7 -_2 )
# + 0.010700382853445958 * ( +_0 +_13 -_7 -_6 )
# + 0.006937845359291027 * ( +_0 +_13 -_8 -_2 )
# + 0.009153660346168518 * ( +_0 +_13 -_8 -_6 )
# + 0.18120093908141943 * ( +_0 +_13 -_9 -_0 )
# + -0.0037527659391431 * ( +_0 +_13 -_9 -_1 )
# + -0.00041294099730659976 * ( +_0 +_13 -_9 -_3 )
# + -0.003494983782990666 * ( +_0 +_13 -_9 -_5 )
# + -0.004818402181974994 * ( +_0 +_13 -_10 -_2 )
# + -0.006602180403890642 * ( +_0 +_13 -_10 -_6 )
# + 0.0046073889800764736 * ( +_0 +_13 -_12 -_2 )
# + 0.0061008351700062805 * ( +_0 +_13 -_12 -_6 )
# + 0.4345426355843152 * ( +_0 +_13 -_13 -_0 )
# + -0.00470159832236389 * ( +_0 +_13 -_13 -_1 )
# + 0.00208452959213619 * ( +_0 +_13 -_13 -_3 )
# + -0.0025667307360305964 * ( +_0 +_13 -_13 -_5 )
# + -0.20831409786744706 * ( +_1 +_0 -_0 -_0 )
# + 0.502275259231326 * ( +_1 +_0 -_0 -_1 )
# + -0.06417601902559864 * ( +_1 +_0 -_0 -_3 )
# + 0.15421006433785528 * ( +_1 +_0 -_0 -_5 )
# + 0.02908506811394313 * ( +_1 +_0 -_1 -_0 )
# + -0.006483470692832997 * ( +_1 +_0 -_1 -_1 )
# + 0.004607064469537394 * ( +_1 +_0 -_1 -_3 )
# + -0.0033248081065072157 * ( +_1 +_0 -_1 -_5 )
# + 0.008884080630837793 * ( +_1 +_0 -_2 -_2 )
# + 0.006937845359291028 * ( +_1 +_0 -_2 -_6 )
# + -0.011246735293008932 * ( +_1 +_0 -_3 -_0 )
# + 0.00803051182981321 * ( +_1 +_0 -_3 -_1 )
# + 0.009464004473381289 * ( +_1 +_0 -_3 -_3 )
# + 0.009325359416068659 * ( +_1 +_0 -_3 -_5 )
# + 0.016230157660897734 * ( +_1 +_0 -_4 -_4 )
# + 0.01790790933556572 * ( +_1 +_0 -_5 -_0 )
# + -0.0003915640669104753 * ( +_1 +_0 -_5 -_1 )
# + 0.010170080326596598 * ( +_1 +_0 -_5 -_3 )
# + 0.003397749886433973 * ( +_1 +_0 -_5 -_5 )
# + 0.01155496272364128 * ( +_1 +_0 -_6 -_2 )
# + 0.00915366034616852 * ( +_1 +_0 -_6 -_6 )
# + 0.029085068113943135 * ( +_1 +_1 -_0 -_0 )
# + -0.006483470692832987 * ( +_1 +_1 -_0 -_1 )
# + 0.004607064469537397 * ( +_1 +_1 -_0 -_3 )
# + -0.00332480810650722 * ( +_1 +_1 -_0 -_5 )
# + -0.0064834706928329705 * ( +_1 +_1 -_1 -_0 )
# + 0.3640999008194573 * ( +_1 +_1 -_1 -_1 )
# + 0.0020803220305167514 * ( +_1 +_1 -_1 -_3 )
# + 0.0714624183037105 * ( +_1 +_1 -_1 -_5 )
# + 0.07223210298809733 * ( +_1 +_1 -_2 -_2 )
# + 0.020153286914855715 * ( +_1 +_1 -_2 -_6 )
# + 0.004607064469537384 * ( +_1 +_1 -_3 -_0 )
# + 0.0020803220305167115 * ( +_1 +_1 -_3 -_1 )
# + 0.06201605272833521 * ( +_1 +_1 -_3 -_3 )
# + 0.010473174371252239 * ( +_1 +_1 -_3 -_5 )
# + 0.07222596701228465 * ( +_1 +_1 -_4 -_4 )
# + -0.00332480810650718 * ( +_1 +_1 -_5 -_0 )
# + 0.07146241830371058 * ( +_1 +_1 -_5 -_1 )
# + 0.010473174371252215 * ( +_1 +_1 -_5 -_3 )
# + 0.05095296969544233 * ( +_1 +_1 -_5 -_5 )
# + 0.02015328691485571 * ( +_1 +_1 -_6 -_2 )
# + 0.030947162200736313 * ( +_1 +_1 -_6 -_6 )
# + 0.008884080630837796 * ( +_1 +_2 -_0 -_2 )
# + 0.006937845359291031 * ( +_1 +_2 -_0 -_6 )
# + 0.07223210298809735 * ( +_1 +_2 -_1 -_2 )
# + 0.020153286914855725 * ( +_1 +_2 -_1 -_6 )
# + -0.002202812656562163 * ( +_1 +_2 -_2 -_0 )
# + 0.3226158567826503 * ( +_1 +_2 -_2 -_1 )
# + 0.0034570647207687127 * ( +_1 +_2 -_2 -_3 )
# + 0.03794457577574586 * ( +_1 +_2 -_2 -_5 )
# + 0.00997685620911435 * ( +_1 +_2 -_3 -_2 )
# + -0.017038397553636446 * ( +_1 +_2 -_3 -_6 )
# + -0.020066409945183463 * ( +_1 +_2 -_5 -_2 )
# + 0.017671246630537246 * ( +_1 +_2 -_5 -_6 )
# + -0.003752765939143107 * ( +_1 +_2 -_6 -_0 )
# + 0.0691248803357372 * ( +_1 +_2 -_6 -_1 )
# + -0.038108313610092724 * ( +_1 +_2 -_6 -_3 )
# + 0.03838066507689976 * ( +_1 +_2 -_6 -_5 )
# + -0.011246735293008927 * ( +_1 +_3 -_0 -_0 )
# + 0.008030511829813215 * ( +_1 +_3 -_0 -_1 )
# + 0.009464004473381292 * ( +_1 +_3 -_0 -_3 )
# + 0.00932535941606867 * ( +_1 +_3 -_0 -_5 )
# + 0.004607064469537396 * ( +_1 +_3 -_1 -_0 )
# + 0.0020803220305167422 * ( +_1 +_3 -_1 -_1 )
# + 0.06201605272833523 * ( +_1 +_3 -_1 -_3 )
# + 0.010473174371252251 * ( +_1 +_3 -_1 -_5 )
# + 0.009976856209114345 * ( +_1 +_3 -_2 -_2 )
# + -0.017038397553636453 * ( +_1 +_3 -_2 -_6 )
# + -0.006786020207397415 * ( +_1 +_3 -_3 -_0 )
# + 0.3378513420057673 * ( +_1 +_3 -_3 -_1 )
# + -0.05223154455503626 * ( +_1 +_3 -_3 -_3 )
# + 0.04414405282767454 * ( +_1 +_3 -_3 -_5 )
# + -0.023452418504650727 * ( +_1 +_3 -_4 -_4 )
# + -0.0011145251113430113 * ( +_1 +_3 -_5 -_0 )
# + 0.047687714705393125 * ( +_1 +_3 -_5 -_1 )
# + -0.01566496251066906 * ( +_1 +_3 -_5 -_3 )
# + 0.030486772061777582 * ( +_1 +_3 -_5 -_5 )
# + -0.038548959937095104 * ( +_1 +_3 -_6 -_2 )
# + -0.008335962519316677 * ( +_1 +_3 -_6 -_6 )
# + 0.016230157660897745 * ( +_1 +_4 -_0 -_4 )
# + 0.07222596701228468 * ( +_1 +_4 -_1 -_4 )
# + -0.023452418504650737 * ( +_1 +_4 -_3 -_4 )
# + -0.005846666275339693 * ( +_1 +_4 -_4 -_0 )
# + 0.3736983434533207 * ( +_1 +_4 -_4 -_1 )
# + -0.03437401218616877 * ( +_1 +_4 -_4 -_3 )
# + 0.07931265007419268 * ( +_1 +_4 -_4 -_5 )
# + 0.02956747456713164 * ( +_1 +_4 -_5 -_4 )
# + 0.017907909335565714 * ( +_1 +_5 -_0 -_0 )
# + -0.0003915640669104891 * ( +_1 +_5 -_0 -_1 )
# + 0.010170080326596604 * ( +_1 +_5 -_0 -_3 )
# + 0.0033977498864339677 * ( +_1 +_5 -_0 -_5 )
# + -0.0033248081065072117 * ( +_1 +_5 -_1 -_0 )
# + 0.07146241830371053 * ( +_1 +_5 -_1 -_1 )
# + 0.010473174371252234 * ( +_1 +_5 -_1 -_3 )
# + 0.05095296969544232 * ( +_1 +_5 -_1 -_5 )
# + -0.020066409945183435 * ( +_1 +_5 -_2 -_2 )
# + 0.01767124663053725 * ( +_1 +_5 -_2 -_6 )
# + -0.0011145251113430042 * ( +_1 +_5 -_3 -_0 )
# + 0.0476877147053931 * ( +_1 +_5 -_3 -_1 )
# + -0.01566496251066908 * ( +_1 +_5 -_3 -_3 )
# + 0.03048677206177759 * ( +_1 +_5 -_3 -_5 )
# + 0.029567474567131623 * ( +_1 +_5 -_4 -_4 )
# + -0.00348856770016543 * ( +_1 +_5 -_5 -_0 )
# + 0.3070976806641894 * ( +_1 +_5 -_5 -_1 )
# + 0.029308499457380507 * ( +_1 +_5 -_5 -_3 )
# + 0.048387852649567804 * ( +_1 +_5 -_5 -_5 )
# + 0.049321930536518094 * ( +_1 +_5 -_6 -_2 )
# + -0.004977329876101959 * ( +_1 +_5 -_6 -_6 )
# + 0.011554962723641288 * ( +_1 +_6 -_0 -_2 )
# + 0.009153660346168532 * ( +_1 +_6 -_0 -_6 )
# + 0.02015328691485572 * ( +_1 +_6 -_1 -_2 )
# + 0.03094716220073635 * ( +_1 +_6 -_1 -_6 )
# + -0.003752765939143107 * ( +_1 +_6 -_2 -_0 )
# + 0.0691248803357372 * ( +_1 +_6 -_2 -_1 )
# + -0.03810831361009272 * ( +_1 +_6 -_2 -_3 )
# + 0.03838066507689973 * ( +_1 +_6 -_2 -_5 )
# + -0.0385489599370951 * ( +_1 +_6 -_3 -_2 )
# + -0.008335962519316708 * ( +_1 +_6 -_3 -_6 )
# + 0.049321930536518094 * ( +_1 +_6 -_5 -_2 )
# + -0.004977329876101942 * ( +_1 +_6 -_5 -_6 )
# + -0.004701598322363933 * ( +_1 +_6 -_6 -_0 )
# + 0.31214586010514317 * ( +_1 +_6 -_6 -_1 )
# + -0.006910419847961721 * ( +_1 +_6 -_6 -_3 )
# + 0.03453719028495603 * ( +_1 +_6 -_6 -_5 )
# + -0.20831409786744706 * ( +_1 +_7 -_7 -_0 )
# + 0.502275259231326 * ( +_1 +_7 -_7 -_1 )
# + -0.06417601902559864 * ( +_1 +_7 -_7 -_3 )
# + 0.15421006433785528 * ( +_1 +_7 -_7 -_5 )
# + 0.02908506811394313 * ( +_1 +_7 -_8 -_0 )
# + -0.006483470692832997 * ( +_1 +_7 -_8 -_1 )
# + 0.004607064469537394 * ( +_1 +_7 -_8 -_3 )
# + -0.0033248081065072157 * ( +_1 +_7 -_8 -_5 )
# + 0.008884080630837793 * ( +_1 +_7 -_9 -_2 )
# + 0.006937845359291028 * ( +_1 +_7 -_9 -_6 )
# + -0.011246735293008932 * ( +_1 +_7 -_10 -_0 )
# + 0.00803051182981321 * ( +_1 +_7 -_10 -_1 )
# + 0.009464004473381289 * ( +_1 +_7 -_10 -_3 )
# + 0.009325359416068659 * ( +_1 +_7 -_10 -_5 )
# + 0.016230157660897734 * ( +_1 +_7 -_11 -_4 )
# + 0.01790790933556572 * ( +_1 +_7 -_12 -_0 )
# + -0.0003915640669104753 * ( +_1 +_7 -_12 -_1 )
# + 0.010170080326596598 * ( +_1 +_7 -_12 -_3 )
# + 0.003397749886433973 * ( +_1 +_7 -_12 -_5 )
# + 0.01155496272364128 * ( +_1 +_7 -_13 -_2 )
# + 0.00915366034616852 * ( +_1 +_7 -_13 -_6 )
# + 0.029085068113943135 * ( +_1 +_8 -_7 -_0 )
# + -0.006483470692832987 * ( +_1 +_8 -_7 -_1 )
# + 0.004607064469537397 * ( +_1 +_8 -_7 -_3 )
# + -0.00332480810650722 * ( +_1 +_8 -_7 -_5 )
# + -0.0064834706928329705 * ( +_1 +_8 -_8 -_0 )
# + 0.3640999008194573 * ( +_1 +_8 -_8 -_1 )
# + 0.0020803220305167514 * ( +_1 +_8 -_8 -_3 )
# + 0.0714624183037105 * ( +_1 +_8 -_8 -_5 )
# + 0.07223210298809733 * ( +_1 +_8 -_9 -_2 )
# + 0.020153286914855715 * ( +_1 +_8 -_9 -_6 )
# + 0.004607064469537384 * ( +_1 +_8 -_10 -_0 )
# + 0.0020803220305167115 * ( +_1 +_8 -_10 -_1 )
# + 0.06201605272833521 * ( +_1 +_8 -_10 -_3 )
# + 0.010473174371252239 * ( +_1 +_8 -_10 -_5 )
# + 0.07222596701228465 * ( +_1 +_8 -_11 -_4 )
# + -0.00332480810650718 * ( +_1 +_8 -_12 -_0 )
# + 0.07146241830371058 * ( +_1 +_8 -_12 -_1 )
# + 0.010473174371252215 * ( +_1 +_8 -_12 -_3 )
# + 0.05095296969544233 * ( +_1 +_8 -_12 -_5 )
# + 0.02015328691485571 * ( +_1 +_8 -_13 -_2 )
# + 0.030947162200736313 * ( +_1 +_8 -_13 -_6 )
# + 0.008884080630837796 * ( +_1 +_9 -_7 -_2 )
# + 0.006937845359291031 * ( +_1 +_9 -_7 -_6 )
# + 0.07223210298809735 * ( +_1 +_9 -_8 -_2 )
# + 0.020153286914855725 * ( +_1 +_9 -_8 -_6 )
# + -0.002202812656562163 * ( +_1 +_9 -_9 -_0 )
# + 0.3226158567826503 * ( +_1 +_9 -_9 -_1 )
# + 0.0034570647207687127 * ( +_1 +_9 -_9 -_3 )
# + 0.03794457577574586 * ( +_1 +_9 -_9 -_5 )
# + 0.00997685620911435 * ( +_1 +_9 -_10 -_2 )
# + -0.017038397553636446 * ( +_1 +_9 -_10 -_6 )
# + -0.020066409945183463 * ( +_1 +_9 -_12 -_2 )
# + 0.017671246630537246 * ( +_1 +_9 -_12 -_6 )
# + -0.003752765939143107 * ( +_1 +_9 -_13 -_0 )
# + 0.0691248803357372 * ( +_1 +_9 -_13 -_1 )
# + -0.038108313610092724 * ( +_1 +_9 -_13 -_3 )
# + 0.03838066507689976 * ( +_1 +_9 -_13 -_5 )
# + -0.011246735293008927 * ( +_1 +_10 -_7 -_0 )
# + 0.008030511829813215 * ( +_1 +_10 -_7 -_1 )
# + 0.009464004473381292 * ( +_1 +_10 -_7 -_3 )
# + 0.00932535941606867 * ( +_1 +_10 -_7 -_5 )
# + 0.004607064469537396 * ( +_1 +_10 -_8 -_0 )
# + 0.0020803220305167422 * ( +_1 +_10 -_8 -_1 )
# + 0.06201605272833523 * ( +_1 +_10 -_8 -_3 )
# + 0.010473174371252251 * ( +_1 +_10 -_8 -_5 )
# + 0.009976856209114345 * ( +_1 +_10 -_9 -_2 )
# + -0.017038397553636453 * ( +_1 +_10 -_9 -_6 )
# + -0.006786020207397415 * ( +_1 +_10 -_10 -_0 )
# + 0.3378513420057673 * ( +_1 +_10 -_10 -_1 )
# + -0.05223154455503626 * ( +_1 +_10 -_10 -_3 )
# + 0.04414405282767454 * ( +_1 +_10 -_10 -_5 )
# + -0.023452418504650727 * ( +_1 +_10 -_11 -_4 )
# + -0.0011145251113430113 * ( +_1 +_10 -_12 -_0 )
# + 0.047687714705393125 * ( +_1 +_10 -_12 -_1 )
# + -0.01566496251066906 * ( +_1 +_10 -_12 -_3 )
# + 0.030486772061777582 * ( +_1 +_10 -_12 -_5 )
# + -0.038548959937095104 * ( +_1 +_10 -_13 -_2 )
# + -0.008335962519316677 * ( +_1 +_10 -_13 -_6 )
# + 0.016230157660897745 * ( +_1 +_11 -_7 -_4 )
# + 0.07222596701228468 * ( +_1 +_11 -_8 -_4 )
# + -0.023452418504650737 * ( +_1 +_11 -_10 -_4 )
# + -0.005846666275339693 * ( +_1 +_11 -_11 -_0 )
# + 0.3736983434533207 * ( +_1 +_11 -_11 -_1 )
# + -0.03437401218616877 * ( +_1 +_11 -_11 -_3 )
# + 0.07931265007419268 * ( +_1 +_11 -_11 -_5 )
# + 0.02956747456713164 * ( +_1 +_11 -_12 -_4 )
# + 0.017907909335565714 * ( +_1 +_12 -_7 -_0 )
# + -0.0003915640669104891 * ( +_1 +_12 -_7 -_1 )
# + 0.010170080326596604 * ( +_1 +_12 -_7 -_3 )
# + 0.0033977498864339677 * ( +_1 +_12 -_7 -_5 )
# + -0.0033248081065072117 * ( +_1 +_12 -_8 -_0 )
# + 0.07146241830371053 * ( +_1 +_12 -_8 -_1 )
# + 0.010473174371252234 * ( +_1 +_12 -_8 -_3 )
# + 0.05095296969544232 * ( +_1 +_12 -_8 -_5 )
# + -0.020066409945183435 * ( +_1 +_12 -_9 -_2 )
# + 0.01767124663053725 * ( +_1 +_12 -_9 -_6 )
# + -0.0011145251113430042 * ( +_1 +_12 -_10 -_0 )
# + 0.0476877147053931 * ( +_1 +_12 -_10 -_1 )
# + -0.01566496251066908 * ( +_1 +_12 -_10 -_3 )
# + 0.03048677206177759 * ( +_1 +_12 -_10 -_5 )
# + 0.029567474567131623 * ( +_1 +_12 -_11 -_4 )
# + -0.00348856770016543 * ( +_1 +_12 -_12 -_0 )
# + 0.3070976806641894 * ( +_1 +_12 -_12 -_1 )
# + 0.029308499457380507 * ( +_1 +_12 -_12 -_3 )
# + 0.048387852649567804 * ( +_1 +_12 -_12 -_5 )
# + 0.049321930536518094 * ( +_1 +_12 -_13 -_2 )
# + -0.004977329876101959 * ( +_1 +_12 -_13 -_6 )
# + 0.011554962723641288 * ( +_1 +_13 -_7 -_2 )
# + 0.009153660346168532 * ( +_1 +_13 -_7 -_6 )
# + 0.02015328691485572 * ( +_1 +_13 -_8 -_2 )
# + 0.03094716220073635 * ( +_1 +_13 -_8 -_6 )
# + -0.003752765939143107 * ( +_1 +_13 -_9 -_0 )
# + 0.0691248803357372 * ( +_1 +_13 -_9 -_1 )
# + -0.03810831361009272 * ( +_1 +_13 -_9 -_3 )
# + 0.03838066507689973 * ( +_1 +_13 -_9 -_5 )
# + -0.0385489599370951 * ( +_1 +_13 -_10 -_2 )
# + -0.008335962519316708 * ( +_1 +_13 -_10 -_6 )
# + 0.049321930536518094 * ( +_1 +_13 -_12 -_2 )
# + -0.004977329876101942 * ( +_1 +_13 -_12 -_6 )
# + -0.004701598322363933 * ( +_1 +_13 -_13 -_0 )
# + 0.31214586010514317 * ( +_1 +_13 -_13 -_1 )
# + -0.006910419847961721 * ( +_1 +_13 -_13 -_3 )
# + 0.03453719028495603 * ( +_1 +_13 -_13 -_5 )
# + 0.40002207402677137 * ( +_2 +_0 -_0 -_2 )
# + 0.18120093908141952 * ( +_2 +_0 -_0 -_6 )
# + -0.0022028126565622193 * ( +_2 +_0 -_1 -_2 )
# + -0.0037527659391431542 * ( +_2 +_0 -_1 -_6 )
# + 0.005497597716048515 * ( +_2 +_0 -_2 -_0 )
# + 0.008884080630837793 * ( +_2 +_0 -_2 -_1 )
# + -0.0017204315837104666 * ( +_2 +_0 -_2 -_3 )
# + 0.0015748818522589032 * ( +_2 +_0 -_2 -_5 )
# + 0.003235298548729189 * ( +_2 +_0 -_3 -_2 )
# + -0.00041294099730657775 * ( +_2 +_0 -_3 -_6 )
# + 9.850026333887659e-05 * ( +_2 +_0 -_5 -_2 )
# + -0.0034949837829906967 * ( +_2 +_0 -_5 -_6 )
# + 0.00765948586953351 * ( +_2 +_0 -_6 -_0 )
# + 0.01155496272364128 * ( +_2 +_0 -_6 -_1 )
# + -0.0024812132230725907 * ( +_2 +_0 -_6 -_3 )
# + 0.001932282093680618 * ( +_2 +_0 -_6 -_5 )
# + -0.0022028126565622015 * ( +_2 +_1 -_0 -_2 )
# + -0.00375276593914312 * ( +_2 +_1 -_0 -_6 )
# + 0.32261585678265037 * ( +_2 +_1 -_1 -_2 )
# + 0.06912488033573723 * ( +_2 +_1 -_1 -_6 )
# + 0.008884080630837793 * ( +_2 +_1 -_2 -_0 )
# + 0.07223210298809735 * ( +_2 +_1 -_2 -_1 )
# + 0.009976856209114354 * ( +_2 +_1 -_2 -_3 )
# + -0.02006640994518348 * ( +_2 +_1 -_2 -_5 )
# + 0.0034570647207687105 * ( +_2 +_1 -_3 -_2 )
# + -0.03810831361009275 * ( +_2 +_1 -_3 -_6 )
# + 0.03794457577574584 * ( +_2 +_1 -_5 -_2 )
# + 0.03838066507689988 * ( +_2 +_1 -_5 -_6 )
# + 0.006937845359291029 * ( +_2 +_1 -_6 -_0 )
# + 0.020153286914855722 * ( +_2 +_1 -_6 -_1 )
# + -0.017038397553636415 * ( +_2 +_1 -_6 -_3 )
# + 0.017671246630537197 * ( +_2 +_1 -_6 -_5 )
# + 0.005497597716048517 * ( +_2 +_2 -_0 -_0 )
# + 0.008884080630837796 * ( +_2 +_2 -_0 -_1 )
# + -0.001720431583710467 * ( +_2 +_2 -_0 -_3 )
# + 0.001574881852258905 * ( +_2 +_2 -_0 -_5 )
# + 0.008884080630837793 * ( +_2 +_2 -_1 -_0 )
# + 0.07223210298809735 * ( +_2 +_2 -_1 -_1 )
# + 0.009976856209114359 * ( +_2 +_2 -_1 -_3 )
# + -0.020066409945183477 * ( +_2 +_2 -_1 -_5 )
# + 0.31655434833208373 * ( +_2 +_2 -_2 -_2 )
# + 0.04521165100513537 * ( +_2 +_2 -_2 -_6 )
# + -0.0017204315837104653 * ( +_2 +_2 -_3 -_0 )
# + 0.00997685620911435 * ( +_2 +_2 -_3 -_1 )
# + 0.023614858999919015 * ( +_2 +_2 -_3 -_3 )
# + -0.014293177994958592 * ( +_2 +_2 -_3 -_5 )
# + 0.014403922240614245 * ( +_2 +_2 -_4 -_4 )
# + 0.0015748818522589038 * ( +_2 +_2 -_5 -_0 )
# + -0.02006640994518347 * ( +_2 +_2 -_5 -_1 )
# + -0.014293177994958607 * ( +_2 +_2 -_5 -_3 )
# + 0.03546339523637596 * ( +_2 +_2 -_5 -_5 )
# + 0.04521165100513532 * ( +_2 +_2 -_6 -_2 )
# + 0.07623119004546165 * ( +_2 +_2 -_6 -_6 )
# + 0.003235298548729172 * ( +_2 +_3 -_0 -_2 )
# + -0.00041294099730659585 * ( +_2 +_3 -_0 -_6 )
# + 0.0034570647207686866 * ( +_2 +_3 -_1 -_2 )
# + -0.03810831361009276 * ( +_2 +_3 -_1 -_6 )
# + -0.0017204315837104649 * ( +_2 +_3 -_2 -_0 )
# + 0.00997685620911434 * ( +_2 +_3 -_2 -_1 )
# + 0.023614858999919015 * ( +_2 +_3 -_2 -_3 )
# + -0.014293177994958588 * ( +_2 +_3 -_2 -_5 )
# + 0.2992996112392815 * ( +_2 +_3 -_3 -_2 )
# + 0.08004713990682992 * ( +_2 +_3 -_3 -_6 )
# + 0.021613099012109636 * ( +_2 +_3 -_5 -_2 )
# + 0.0391995757042592 * ( +_2 +_3 -_5 -_6 )
# + -0.004818402181974995 * ( +_2 +_3 -_6 -_0 )
# + -0.03854895993709512 * ( +_2 +_3 -_6 -_1 )
# + 0.0011628804655886332 * ( +_2 +_3 -_6 -_3 )
# + 0.022211985850562006 * ( +_2 +_3 -_6 -_5 )
# + 0.014403922240614243 * ( +_2 +_4 -_2 -_4 )
# + 0.31447975986565013 * ( +_2 +_4 -_4 -_2 )
# + 0.09489475017438127 * ( +_2 +_4 -_4 -_6 )
# + 0.011843706720007039 * ( +_2 +_4 -_6 -_4 )
# + 9.85002633389051e-05 * ( +_2 +_5 -_0 -_2 )
# + -0.003494983782990663 * ( +_2 +_5 -_0 -_6 )
# + 0.03794457577574594 * ( +_2 +_5 -_1 -_2 )
# + 0.03838066507689991 * ( +_2 +_5 -_1 -_6 )
# + 0.001574881852258905 * ( +_2 +_5 -_2 -_0 )
# + -0.020066409945183446 * ( +_2 +_5 -_2 -_1 )
# + -0.014293177994958614 * ( +_2 +_5 -_2 -_3 )
# + 0.03546339523637597 * ( +_2 +_5 -_2 -_5 )
# + 0.02161309901210971 * ( +_2 +_5 -_3 -_2 )
# + 0.03919957570425924 * ( +_2 +_5 -_3 -_6 )
# + 0.2857472339123343 * ( +_2 +_5 -_5 -_2 )
# + 0.01896584969803087 * ( +_2 +_5 -_5 -_6 )
# + 0.00460738898007647 * ( +_2 +_5 -_6 -_0 )
# + 0.049321930536518135 * ( +_2 +_5 -_6 -_1 )
# + 0.02380754525594564 * ( +_2 +_5 -_6 -_3 )
# + -0.032264030275975235 * ( +_2 +_5 -_6 -_5 )
# + 0.0076594858695335135 * ( +_2 +_6 -_0 -_0 )
# + 0.011554962723641286 * ( +_2 +_6 -_0 -_1 )
# + -0.0024812132230725955 * ( +_2 +_6 -_0 -_3 )
# + 0.001932282093680625 * ( +_2 +_6 -_0 -_5 )
# + 0.006937845359291033 * ( +_2 +_6 -_1 -_0 )
# + 0.02015328691485573 * ( +_2 +_6 -_1 -_1 )
# + -0.01703839755363642 * ( +_2 +_6 -_1 -_3 )
# + 0.017671246630537193 * ( +_2 +_6 -_1 -_5 )
# + 0.0452116510051353 * ( +_2 +_6 -_2 -_2 )
# + 0.07623119004546168 * ( +_2 +_6 -_2 -_6 )
# + -0.004818402181974998 * ( +_2 +_6 -_3 -_0 )
# + -0.038548959937095104 * ( +_2 +_6 -_3 -_1 )
# + 0.0011628804655886363 * ( +_2 +_6 -_3 -_3 )
# + 0.022211985850562027 * ( +_2 +_6 -_3 -_5 )
# + 0.011843706720007039 * ( +_2 +_6 -_4 -_4 )
# + 0.004607388980076475 * ( +_2 +_6 -_5 -_0 )
# + 0.049321930536518115 * ( +_2 +_6 -_5 -_1 )
# + 0.023807545255945625 * ( +_2 +_6 -_5 -_3 )
# + -0.03226403027597526 * ( +_2 +_6 -_5 -_5 )
# + 0.3054172325252666 * ( +_2 +_6 -_6 -_2 )
# + 0.04661383511342053 * ( +_2 +_6 -_6 -_6 )
# + 0.40002207402677137 * ( +_2 +_7 -_7 -_2 )
# + 0.18120093908141952 * ( +_2 +_7 -_7 -_6 )
# + -0.0022028126565622193 * ( +_2 +_7 -_8 -_2 )
# + -0.0037527659391431542 * ( +_2 +_7 -_8 -_6 )
# + 0.005497597716048515 * ( +_2 +_7 -_9 -_0 )
# + 0.008884080630837793 * ( +_2 +_7 -_9 -_1 )
# + -0.0017204315837104666 * ( +_2 +_7 -_9 -_3 )
# + 0.0015748818522589032 * ( +_2 +_7 -_9 -_5 )
# + 0.003235298548729189 * ( +_2 +_7 -_10 -_2 )
# + -0.00041294099730657775 * ( +_2 +_7 -_10 -_6 )
# + 9.850026333887659e-05 * ( +_2 +_7 -_12 -_2 )
# + -0.0034949837829906967 * ( +_2 +_7 -_12 -_6 )
# + 0.00765948586953351 * ( +_2 +_7 -_13 -_0 )
# + 0.01155496272364128 * ( +_2 +_7 -_13 -_1 )
# + -0.0024812132230725907 * ( +_2 +_7 -_13 -_3 )
# + 0.001932282093680618 * ( +_2 +_7 -_13 -_5 )
# + -0.0022028126565622015 * ( +_2 +_8 -_7 -_2 )
# + -0.00375276593914312 * ( +_2 +_8 -_7 -_6 )
# + 0.32261585678265037 * ( +_2 +_8 -_8 -_2 )
# + 0.06912488033573723 * ( +_2 +_8 -_8 -_6 )
# + 0.008884080630837793 * ( +_2 +_8 -_9 -_0 )
# + 0.07223210298809735 * ( +_2 +_8 -_9 -_1 )
# + 0.009976856209114354 * ( +_2 +_8 -_9 -_3 )
# + -0.02006640994518348 * ( +_2 +_8 -_9 -_5 )
# + 0.0034570647207687105 * ( +_2 +_8 -_10 -_2 )
# + -0.03810831361009275 * ( +_2 +_8 -_10 -_6 )
# + 0.03794457577574584 * ( +_2 +_8 -_12 -_2 )
# + 0.03838066507689988 * ( +_2 +_8 -_12 -_6 )
# + 0.006937845359291029 * ( +_2 +_8 -_13 -_0 )
# + 0.020153286914855722 * ( +_2 +_8 -_13 -_1 )
# + -0.017038397553636415 * ( +_2 +_8 -_13 -_3 )
# + 0.017671246630537197 * ( +_2 +_8 -_13 -_5 )
# + 0.005497597716048517 * ( +_2 +_9 -_7 -_0 )
# + 0.008884080630837796 * ( +_2 +_9 -_7 -_1 )
# + -0.001720431583710467 * ( +_2 +_9 -_7 -_3 )
# + 0.001574881852258905 * ( +_2 +_9 -_7 -_5 )
# + 0.008884080630837793 * ( +_2 +_9 -_8 -_0 )
# + 0.07223210298809735 * ( +_2 +_9 -_8 -_1 )
# + 0.009976856209114359 * ( +_2 +_9 -_8 -_3 )
# + -0.020066409945183477 * ( +_2 +_9 -_8 -_5 )
# + 0.31655434833208373 * ( +_2 +_9 -_9 -_2 )
# + 0.04521165100513537 * ( +_2 +_9 -_9 -_6 )
# + -0.0017204315837104653 * ( +_2 +_9 -_10 -_0 )
# + 0.00997685620911435 * ( +_2 +_9 -_10 -_1 )
# + 0.023614858999919015 * ( +_2 +_9 -_10 -_3 )
# + -0.014293177994958592 * ( +_2 +_9 -_10 -_5 )
# + 0.014403922240614245 * ( +_2 +_9 -_11 -_4 )
# + 0.0015748818522589038 * ( +_2 +_9 -_12 -_0 )
# + -0.02006640994518347 * ( +_2 +_9 -_12 -_1 )
# + -0.014293177994958607 * ( +_2 +_9 -_12 -_3 )
# + 0.03546339523637596 * ( +_2 +_9 -_12 -_5 )
# + 0.04521165100513532 * ( +_2 +_9 -_13 -_2 )
# + 0.07623119004546165 * ( +_2 +_9 -_13 -_6 )
# + 0.003235298548729172 * ( +_2 +_10 -_7 -_2 )
# + -0.00041294099730659585 * ( +_2 +_10 -_7 -_6 )
# + 0.0034570647207686866 * ( +_2 +_10 -_8 -_2 )
# + -0.03810831361009276 * ( +_2 +_10 -_8 -_6 )
# + -0.0017204315837104649 * ( +_2 +_10 -_9 -_0 )
# + 0.00997685620911434 * ( +_2 +_10 -_9 -_1 )
# + 0.023614858999919015 * ( +_2 +_10 -_9 -_3 )
# + -0.014293177994958588 * ( +_2 +_10 -_9 -_5 )
# + 0.2992996112392815 * ( +_2 +_10 -_10 -_2 )
# + 0.08004713990682992 * ( +_2 +_10 -_10 -_6 )
# + 0.021613099012109636 * ( +_2 +_10 -_12 -_2 )
# + 0.0391995757042592 * ( +_2 +_10 -_12 -_6 )
# + -0.004818402181974995 * ( +_2 +_10 -_13 -_0 )
# + -0.03854895993709512 * ( +_2 +_10 -_13 -_1 )
# + 0.0011628804655886332 * ( +_2 +_10 -_13 -_3 )
# + 0.022211985850562006 * ( +_2 +_10 -_13 -_5 )
# + 0.014403922240614243 * ( +_2 +_11 -_9 -_4 )
# + 0.31447975986565013 * ( +_2 +_11 -_11 -_2 )
# + 0.09489475017438127 * ( +_2 +_11 -_11 -_6 )
# + 0.011843706720007039 * ( +_2 +_11 -_13 -_4 )
# + 9.85002633389051e-05 * ( +_2 +_12 -_7 -_2 )
# + -0.003494983782990663 * ( +_2 +_12 -_7 -_6 )
# + 0.03794457577574594 * ( +_2 +_12 -_8 -_2 )
# + 0.03838066507689991 * ( +_2 +_12 -_8 -_6 )
# + 0.001574881852258905 * ( +_2 +_12 -_9 -_0 )
# + -0.020066409945183446 * ( +_2 +_12 -_9 -_1 )
# + -0.014293177994958614 * ( +_2 +_12 -_9 -_3 )
# + 0.03546339523637597 * ( +_2 +_12 -_9 -_5 )
# + 0.02161309901210971 * ( +_2 +_12 -_10 -_2 )
# + 0.03919957570425924 * ( +_2 +_12 -_10 -_6 )
# + 0.2857472339123343 * ( +_2 +_12 -_12 -_2 )
# + 0.01896584969803087 * ( +_2 +_12 -_12 -_6 )
# + 0.00460738898007647 * ( +_2 +_12 -_13 -_0 )
# + 0.049321930536518135 * ( +_2 +_12 -_13 -_1 )
# + 0.02380754525594564 * ( +_2 +_12 -_13 -_3 )
# + -0.032264030275975235 * ( +_2 +_12 -_13 -_5 )
# + 0.0076594858695335135 * ( +_2 +_13 -_7 -_0 )
# + 0.011554962723641286 * ( +_2 +_13 -_7 -_1 )
# + -0.0024812132230725955 * ( +_2 +_13 -_7 -_3 )
# + 0.001932282093680625 * ( +_2 +_13 -_7 -_5 )
# + 0.006937845359291033 * ( +_2 +_13 -_8 -_0 )
# + 0.02015328691485573 * ( +_2 +_13 -_8 -_1 )
# + -0.01703839755363642 * ( +_2 +_13 -_8 -_3 )
# + 0.017671246630537193 * ( +_2 +_13 -_8 -_5 )
# + 0.0452116510051353 * ( +_2 +_13 -_9 -_2 )
# + 0.07623119004546168 * ( +_2 +_13 -_9 -_6 )
# + -0.004818402181974998 * ( +_2 +_13 -_10 -_0 )
# + -0.038548959937095104 * ( +_2 +_13 -_10 -_1 )
# + 0.0011628804655886363 * ( +_2 +_13 -_10 -_3 )
# + 0.022211985850562027 * ( +_2 +_13 -_10 -_5 )
# + 0.011843706720007039 * ( +_2 +_13 -_11 -_4 )
# + 0.004607388980076475 * ( +_2 +_13 -_12 -_0 )
# + 0.049321930536518115 * ( +_2 +_13 -_12 -_1 )
# + 0.023807545255945625 * ( +_2 +_13 -_12 -_3 )
# + -0.03226403027597526 * ( +_2 +_13 -_12 -_5 )
# + 0.3054172325252666 * ( +_2 +_13 -_13 -_2 )
# + 0.04661383511342053 * ( +_2 +_13 -_13 -_6 )
# + 0.09180183646543418 * ( +_3 +_0 -_0 -_0 )
# + -0.06417601902559869 * ( +_3 +_0 -_0 -_1 )
# + 0.5000018268716423 * ( +_3 +_0 -_0 -_3 )
# + 0.1096066582099838 * ( +_3 +_0 -_0 -_5 )
# + -0.01124673529300893 * ( +_3 +_0 -_1 -_0 )
# + 0.004607064469537413 * ( +_3 +_0 -_1 -_1 )
# + -0.006786020207397527 * ( +_3 +_0 -_1 -_3 )
# + -0.0011145251113429927 * ( +_3 +_0 -_1 -_5 )
# + -0.0017204315837104646 * ( +_3 +_0 -_2 -_2 )
# + -0.004818402181974998 * ( +_3 +_0 -_2 -_6 )
# + 0.0138911058913937 * ( +_3 +_0 -_3 -_0 )
# + 0.00946400447338128 * ( +_3 +_0 -_3 -_1 )
# + -0.005686108941104472 * ( +_3 +_0 -_3 -_3 )
# + 0.001174443918429111 * ( +_3 +_0 -_3 -_5 )
# + -0.006725730203450188 * ( +_3 +_0 -_4 -_4 )
# + -0.0002864078952772545 * ( +_3 +_0 -_5 -_0 )
# + 0.010170080326596618 * ( +_3 +_0 -_5 -_1 )
# + -0.009621901749820604 * ( +_3 +_0 -_5 -_3 )
# + -0.00013734154277086062 * ( +_3 +_0 -_5 -_5 )
# + -0.0024812132230725916 * ( +_3 +_0 -_6 -_2 )
# + -0.006602180403890645 * ( +_3 +_0 -_6 -_6 )
# + -0.011246735293008937 * ( +_3 +_1 -_0 -_0 )
# + 0.004607064469537412 * ( +_3 +_1 -_0 -_1 )
# + -0.006786020207397482 * ( +_3 +_1 -_0 -_3 )
# + -0.0011145251113429849 * ( +_3 +_1 -_0 -_5 )
# + 0.008030511829813205 * ( +_3 +_1 -_1 -_0 )
# + 0.0020803220305167635 * ( +_3 +_1 -_1 -_1 )
# + 0.3378513420057674 * ( +_3 +_1 -_1 -_3 )
# + 0.0476877147053933 * ( +_3 +_1 -_1 -_5 )
# + 0.009976856209114348 * ( +_3 +_1 -_2 -_2 )
# + -0.03854895993709509 * ( +_3 +_1 -_2 -_6 )
# + 0.009464004473381289 * ( +_3 +_1 -_3 -_0 )
# + 0.062016052728335186 * ( +_3 +_1 -_3 -_1 )
# + -0.05223154455503626 * ( +_3 +_1 -_3 -_3 )
# + -0.015664962510669223 * ( +_3 +_1 -_3 -_5 )
# + -0.023452418504650737 * ( +_3 +_1 -_4 -_4 )
# + 0.009325359416068647 * ( +_3 +_1 -_5 -_0 )
# + 0.010473174371252265 * ( +_3 +_1 -_5 -_1 )
# + 0.04414405282767461 * ( +_3 +_1 -_5 -_3 )
# + 0.03048677206177779 * ( +_3 +_1 -_5 -_5 )
# + -0.01703839755363641 * ( +_3 +_1 -_6 -_2 )
# + -0.008335962519316733 * ( +_3 +_1 -_6 -_6 )
# + -0.0017204315837104672 * ( +_3 +_2 -_0 -_2 )
# + -0.004818402181974999 * ( +_3 +_2 -_0 -_6 )
# + 0.009976856209114355 * ( +_3 +_2 -_1 -_2 )
# + -0.038548959937095124 * ( +_3 +_2 -_1 -_6 )
# + 0.0032352985487291595 * ( +_3 +_2 -_2 -_0 )
# + 0.0034570647207686953 * ( +_3 +_2 -_2 -_1 )
# + 0.29929961123928156 * ( +_3 +_2 -_2 -_3 )
# + 0.021613099012109664 * ( +_3 +_2 -_2 -_5 )
# + 0.02361485899991901 * ( +_3 +_2 -_3 -_2 )
# + 0.0011628804655886569 * ( +_3 +_2 -_3 -_6 )
# + -0.014293177994958604 * ( +_3 +_2 -_5 -_2 )
# + 0.022211985850561985 * ( +_3 +_2 -_5 -_6 )
# + -0.0004129409973065946 * ( +_3 +_2 -_6 -_0 )
# + -0.03810831361009273 * ( +_3 +_2 -_6 -_1 )
# + 0.08004713990682982 * ( +_3 +_2 -_6 -_3 )
# + 0.0391995757042593 * ( +_3 +_2 -_6 -_5 )
# + 0.013891105891393704 * ( +_3 +_3 -_0 -_0 )
# + 0.009464004473381284 * ( +_3 +_3 -_0 -_1 )
# + -0.005686108941104493 * ( +_3 +_3 -_0 -_3 )
# + 0.0011744439184291143 * ( +_3 +_3 -_0 -_5 )
# + 0.009464004473381287 * ( +_3 +_3 -_1 -_0 )
# + 0.06201605272833521 * ( +_3 +_3 -_1 -_1 )
# + -0.05223154455503624 * ( +_3 +_3 -_1 -_3 )
# + -0.015664962510669185 * ( +_3 +_3 -_1 -_5 )
# + 0.023614858999919015 * ( +_3 +_3 -_2 -_2 )
# + 0.0011628804655886432 * ( +_3 +_3 -_2 -_6 )
# + -0.00568610894110451 * ( +_3 +_3 -_3 -_0 )
# + -0.052231544555036244 * ( +_3 +_3 -_3 -_1 )
# + 0.3914635457653559 * ( +_3 +_3 -_3 -_3 )
# + 0.06065508065913006 * ( +_3 +_3 -_3 -_5 )
# + 0.027964238630025562 * ( +_3 +_3 -_4 -_4 )
# + 0.001174443918429129 * ( +_3 +_3 -_5 -_0 )
# + -0.015664962510669116 * ( +_3 +_3 -_5 -_1 )
# + 0.060655080659129994 * ( +_3 +_3 -_5 -_3 )
# + 0.034317491456515435 * ( +_3 +_3 -_5 -_5 )
# + 0.0011628804655886367 * ( +_3 +_3 -_6 -_2 )
# + 0.03447881380615258 * ( +_3 +_3 -_6 -_6 )
# + -0.0067257302034501925 * ( +_3 +_4 -_0 -_4 )
# + -0.023452418504650737 * ( +_3 +_4 -_1 -_4 )
# + 0.02796423863002556 * ( +_3 +_4 -_3 -_4 )
# + 0.0025591240494330586 * ( +_3 +_4 -_4 -_0 )
# + -0.03437401218616874 * ( +_3 +_4 -_4 -_1 )
# + 0.3645034109502648 * ( +_3 +_4 -_4 -_3 )
# + 0.05809306215666287 * ( +_3 +_4 -_4 -_5 )
# + -0.0008824631406980529 * ( +_3 +_4 -_5 -_4 )
# + -0.00028640789527725443 * ( +_3 +_5 -_0 -_0 )
# + 0.010170080326596612 * ( +_3 +_5 -_0 -_1 )
# + -0.0096219017498206 * ( +_3 +_5 -_0 -_3 )
# + -0.00013734154277087298 * ( +_3 +_5 -_0 -_5 )
# + 0.009325359416068671 * ( +_3 +_5 -_1 -_0 )
# + 0.010473174371252251 * ( +_3 +_5 -_1 -_1 )
# + 0.044144052827674585 * ( +_3 +_5 -_1 -_3 )
# + 0.030486772061777755 * ( +_3 +_5 -_1 -_5 )
# + -0.014293177994958613 * ( +_3 +_5 -_2 -_2 )
# + 0.022211985850562017 * ( +_3 +_5 -_2 -_6 )
# + 0.0011744439184291204 * ( +_3 +_5 -_3 -_0 )
# + -0.015664962510669123 * ( +_3 +_5 -_3 -_1 )
# + 0.060655080659129994 * ( +_3 +_5 -_3 -_3 )
# + 0.0343174914565154 * ( +_3 +_5 -_3 -_5 )
# + -0.0008824631406980554 * ( +_3 +_5 -_4 -_4 )
# + 0.010599008579304011 * ( +_3 +_5 -_5 -_0 )
# + 0.029308499457380517 * ( +_3 +_5 -_5 -_1 )
# + 0.2745316679040245 * ( +_3 +_5 -_5 -_3 )
# + 0.022285875045437453 * ( +_3 +_5 -_5 -_5 )
# + 0.023807545255945622 * ( +_3 +_5 -_6 -_2 )
# + -0.028952272315813352 * ( +_3 +_5 -_6 -_6 )
# + -0.002481213223072594 * ( +_3 +_6 -_0 -_2 )
# + -0.006602180403890651 * ( +_3 +_6 -_0 -_6 )
# + -0.017038397553636418 * ( +_3 +_6 -_1 -_2 )
# + -0.008335962519316719 * ( +_3 +_6 -_1 -_6 )
# + -0.0004129409973065957 * ( +_3 +_6 -_2 -_0 )
# + -0.03810831361009271 * ( +_3 +_6 -_2 -_1 )
# + 0.0800471399068298 * ( +_3 +_6 -_2 -_3 )
# + 0.03919957570425929 * ( +_3 +_6 -_2 -_5 )
# + 0.001162880465588638 * ( +_3 +_6 -_3 -_2 )
# + 0.03447881380615258 * ( +_3 +_6 -_3 -_6 )
# + 0.02380754525594563 * ( +_3 +_6 -_5 -_2 )
# + -0.02895227231581333 * ( +_3 +_6 -_5 -_6 )
# + 0.0020845295921362267 * ( +_3 +_6 -_6 -_0 )
# + -0.00691041984796175 * ( +_3 +_6 -_6 -_1 )
# + 0.30416148680111926 * ( +_3 +_6 -_6 -_3 )
# + 0.02075898004754366 * ( +_3 +_6 -_6 -_5 )
# + 0.09180183646543418 * ( +_3 +_7 -_7 -_0 )
# + -0.06417601902559869 * ( +_3 +_7 -_7 -_1 )
# + 0.5000018268716423 * ( +_3 +_7 -_7 -_3 )
# + 0.1096066582099838 * ( +_3 +_7 -_7 -_5 )
# + -0.01124673529300893 * ( +_3 +_7 -_8 -_0 )
# + 0.004607064469537413 * ( +_3 +_7 -_8 -_1 )
# + -0.006786020207397527 * ( +_3 +_7 -_8 -_3 )
# + -0.0011145251113429927 * ( +_3 +_7 -_8 -_5 )
# + -0.0017204315837104646 * ( +_3 +_7 -_9 -_2 )
# + -0.004818402181974998 * ( +_3 +_7 -_9 -_6 )
# + 0.0138911058913937 * ( +_3 +_7 -_10 -_0 )
# + 0.00946400447338128 * ( +_3 +_7 -_10 -_1 )
# + -0.005686108941104472 * ( +_3 +_7 -_10 -_3 )
# + 0.001174443918429111 * ( +_3 +_7 -_10 -_5 )
# + -0.006725730203450188 * ( +_3 +_7 -_11 -_4 )
# + -0.0002864078952772545 * ( +_3 +_7 -_12 -_0 )
# + 0.010170080326596618 * ( +_3 +_7 -_12 -_1 )
# + -0.009621901749820604 * ( +_3 +_7 -_12 -_3 )
# + -0.00013734154277086062 * ( +_3 +_7 -_12 -_5 )
# + -0.0024812132230725916 * ( +_3 +_7 -_13 -_2 )
# + -0.006602180403890645 * ( +_3 +_7 -_13 -_6 )
# + -0.011246735293008937 * ( +_3 +_8 -_7 -_0 )
# + 0.004607064469537412 * ( +_3 +_8 -_7 -_1 )
# + -0.006786020207397482 * ( +_3 +_8 -_7 -_3 )
# + -0.0011145251113429849 * ( +_3 +_8 -_7 -_5 )
# + 0.008030511829813205 * ( +_3 +_8 -_8 -_0 )
# + 0.0020803220305167635 * ( +_3 +_8 -_8 -_1 )
# + 0.3378513420057674 * ( +_3 +_8 -_8 -_3 )
# + 0.0476877147053933 * ( +_3 +_8 -_8 -_5 )
# + 0.009976856209114348 * ( +_3 +_8 -_9 -_2 )
# + -0.03854895993709509 * ( +_3 +_8 -_9 -_6 )
# + 0.009464004473381289 * ( +_3 +_8 -_10 -_0 )
# + 0.062016052728335186 * ( +_3 +_8 -_10 -_1 )
# + -0.05223154455503626 * ( +_3 +_8 -_10 -_3 )
# + -0.015664962510669223 * ( +_3 +_8 -_10 -_5 )
# + -0.023452418504650737 * ( +_3 +_8 -_11 -_4 )
# + 0.009325359416068647 * ( +_3 +_8 -_12 -_0 )
# + 0.010473174371252265 * ( +_3 +_8 -_12 -_1 )
# + 0.04414405282767461 * ( +_3 +_8 -_12 -_3 )
# + 0.03048677206177779 * ( +_3 +_8 -_12 -_5 )
# + -0.01703839755363641 * ( +_3 +_8 -_13 -_2 )
# + -0.008335962519316733 * ( +_3 +_8 -_13 -_6 )
# + -0.0017204315837104672 * ( +_3 +_9 -_7 -_2 )
# + -0.004818402181974999 * ( +_3 +_9 -_7 -_6 )
# + 0.009976856209114355 * ( +_3 +_9 -_8 -_2 )
# + -0.038548959937095124 * ( +_3 +_9 -_8 -_6 )
# + 0.0032352985487291595 * ( +_3 +_9 -_9 -_0 )
# + 0.0034570647207686953 * ( +_3 +_9 -_9 -_1 )
# + 0.29929961123928156 * ( +_3 +_9 -_9 -_3 )
# + 0.021613099012109664 * ( +_3 +_9 -_9 -_5 )
# + 0.02361485899991901 * ( +_3 +_9 -_10 -_2 )
# + 0.0011628804655886569 * ( +_3 +_9 -_10 -_6 )
# + -0.014293177994958604 * ( +_3 +_9 -_12 -_2 )
# + 0.022211985850561985 * ( +_3 +_9 -_12 -_6 )
# + -0.0004129409973065946 * ( +_3 +_9 -_13 -_0 )
# + -0.03810831361009273 * ( +_3 +_9 -_13 -_1 )
# + 0.08004713990682982 * ( +_3 +_9 -_13 -_3 )
# + 0.0391995757042593 * ( +_3 +_9 -_13 -_5 )
# + 0.013891105891393704 * ( +_3 +_10 -_7 -_0 )
# + 0.009464004473381284 * ( +_3 +_10 -_7 -_1 )
# + -0.005686108941104493 * ( +_3 +_10 -_7 -_3 )
# + 0.0011744439184291143 * ( +_3 +_10 -_7 -_5 )
# + 0.009464004473381287 * ( +_3 +_10 -_8 -_0 )
# + 0.06201605272833521 * ( +_3 +_10 -_8 -_1 )
# + -0.05223154455503624 * ( +_3 +_10 -_8 -_3 )
# + -0.015664962510669185 * ( +_3 +_10 -_8 -_5 )
# + 0.023614858999919015 * ( +_3 +_10 -_9 -_2 )
# + 0.0011628804655886432 * ( +_3 +_10 -_9 -_6 )
# + -0.00568610894110451 * ( +_3 +_10 -_10 -_0 )
# + -0.052231544555036244 * ( +_3 +_10 -_10 -_1 )
# + 0.3914635457653559 * ( +_3 +_10 -_10 -_3 )
# + 0.06065508065913006 * ( +_3 +_10 -_10 -_5 )
# + 0.027964238630025562 * ( +_3 +_10 -_11 -_4 )
# + 0.001174443918429129 * ( +_3 +_10 -_12 -_0 )
# + -0.015664962510669116 * ( +_3 +_10 -_12 -_1 )
# + 0.060655080659129994 * ( +_3 +_10 -_12 -_3 )
# + 0.034317491456515435 * ( +_3 +_10 -_12 -_5 )
# + 0.0011628804655886367 * ( +_3 +_10 -_13 -_2 )
# + 0.03447881380615258 * ( +_3 +_10 -_13 -_6 )
# + -0.0067257302034501925 * ( +_3 +_11 -_7 -_4 )
# + -0.023452418504650737 * ( +_3 +_11 -_8 -_4 )
# + 0.02796423863002556 * ( +_3 +_11 -_10 -_4 )
# + 0.0025591240494330586 * ( +_3 +_11 -_11 -_0 )
# + -0.03437401218616874 * ( +_3 +_11 -_11 -_1 )
# + 0.3645034109502648 * ( +_3 +_11 -_11 -_3 )
# + 0.05809306215666287 * ( +_3 +_11 -_11 -_5 )
# + -0.0008824631406980529 * ( +_3 +_11 -_12 -_4 )
# + -0.00028640789527725443 * ( +_3 +_12 -_7 -_0 )
# + 0.010170080326596612 * ( +_3 +_12 -_7 -_1 )
# + -0.0096219017498206 * ( +_3 +_12 -_7 -_3 )
# + -0.00013734154277087298 * ( +_3 +_12 -_7 -_5 )
# + 0.009325359416068671 * ( +_3 +_12 -_8 -_0 )
# + 0.010473174371252251 * ( +_3 +_12 -_8 -_1 )
# + 0.044144052827674585 * ( +_3 +_12 -_8 -_3 )
# + 0.030486772061777755 * ( +_3 +_12 -_8 -_5 )
# + -0.014293177994958613 * ( +_3 +_12 -_9 -_2 )
# + 0.022211985850562017 * ( +_3 +_12 -_9 -_6 )
# + 0.0011744439184291204 * ( +_3 +_12 -_10 -_0 )
# + -0.015664962510669123 * ( +_3 +_12 -_10 -_1 )
# + 0.060655080659129994 * ( +_3 +_12 -_10 -_3 )
# + 0.0343174914565154 * ( +_3 +_12 -_10 -_5 )
# + -0.0008824631406980554 * ( +_3 +_12 -_11 -_4 )
# + 0.010599008579304011 * ( +_3 +_12 -_12 -_0 )
# + 0.029308499457380517 * ( +_3 +_12 -_12 -_1 )
# + 0.2745316679040245 * ( +_3 +_12 -_12 -_3 )
# + 0.022285875045437453 * ( +_3 +_12 -_12 -_5 )
# + 0.023807545255945622 * ( +_3 +_12 -_13 -_2 )
# + -0.028952272315813352 * ( +_3 +_12 -_13 -_6 )
# + -0.002481213223072594 * ( +_3 +_13 -_7 -_2 )
# + -0.006602180403890651 * ( +_3 +_13 -_7 -_6 )
# + -0.017038397553636418 * ( +_3 +_13 -_8 -_2 )
# + -0.008335962519316719 * ( +_3 +_13 -_8 -_6 )
# + -0.0004129409973065957 * ( +_3 +_13 -_9 -_0 )
# + -0.03810831361009271 * ( +_3 +_13 -_9 -_1 )
# + 0.0800471399068298 * ( +_3 +_13 -_9 -_3 )
# + 0.03919957570425929 * ( +_3 +_13 -_9 -_5 )
# + 0.001162880465588638 * ( +_3 +_13 -_10 -_2 )
# + 0.03447881380615258 * ( +_3 +_13 -_10 -_6 )
# + 0.02380754525594563 * ( +_3 +_13 -_12 -_2 )
# + -0.02895227231581333 * ( +_3 +_13 -_12 -_6 )
# + 0.0020845295921362267 * ( +_3 +_13 -_13 -_0 )
# + -0.00691041984796175 * ( +_3 +_13 -_13 -_1 )
# + 0.30416148680111926 * ( +_3 +_13 -_13 -_3 )
# + 0.02075898004754366 * ( +_3 +_13 -_13 -_5 )
# + 0.5576680951820323 * ( +_4 +_0 -_0 -_4 )
# + -0.005846666275339802 * ( +_4 +_0 -_1 -_4 )
# + 0.002559124049433101 * ( +_4 +_0 -_3 -_4 )
# + 0.013022424695686034 * ( +_4 +_0 -_4 -_0 )
# + 0.016230157660897734 * ( +_4 +_0 -_4 -_1 )
# + -0.006725730203450191 * ( +_4 +_0 -_4 -_3 )
# + 0.007878382769591146 * ( +_4 +_0 -_4 -_5 )
# + -0.003105685015072101 * ( +_4 +_0 -_5 -_4 )
# + -0.005846666275339804 * ( +_4 +_1 -_0 -_4 )
# + 0.3736983434533208 * ( +_4 +_1 -_1 -_4 )
# + -0.03437401218616885 * ( +_4 +_1 -_3 -_4 )
# + 0.01623015766089773 * ( +_4 +_1 -_4 -_0 )
# + 0.07222596701228465 * ( +_4 +_1 -_4 -_1 )
# + -0.023452418504650734 * ( +_4 +_1 -_4 -_3 )
# + 0.029567474567131626 * ( +_4 +_1 -_4 -_5 )
# + 0.07931265007419269 * ( +_4 +_1 -_5 -_4 )
# + 0.3144797598656501 * ( +_4 +_2 -_2 -_4 )
# + 0.014403922240614243 * ( +_4 +_2 -_4 -_2 )
# + 0.011843706720007043 * ( +_4 +_2 -_4 -_6 )
# + 0.09489475017438125 * ( +_4 +_2 -_6 -_4 )
# + 0.002559124049433103 * ( +_4 +_3 -_0 -_4 )
# + -0.0343740121861688 * ( +_4 +_3 -_1 -_4 )
# + 0.3645034109502649 * ( +_4 +_3 -_3 -_4 )
# + -0.006725730203450186 * ( +_4 +_3 -_4 -_0 )
# + -0.023452418504650723 * ( +_4 +_3 -_4 -_1 )
# + 0.027964238630025562 * ( +_4 +_3 -_4 -_3 )
# + -0.0008824631406980499 * ( +_4 +_3 -_4 -_5 )
# + 0.05809306215666283 * ( +_4 +_3 -_5 -_4 )
# + 0.013022424695686038 * ( +_4 +_4 -_0 -_0 )
# + 0.01623015766089774 * ( +_4 +_4 -_0 -_1 )
# + -0.00672573020345019 * ( +_4 +_4 -_0 -_3 )
# + 0.00787838276959115 * ( +_4 +_4 -_0 -_5 )
# + 0.016230157660897738 * ( +_4 +_4 -_1 -_0 )
# + 0.07222596701228466 * ( +_4 +_4 -_1 -_1 )
# + -0.023452418504650737 * ( +_4 +_4 -_1 -_3 )
# + 0.029567474567131623 * ( +_4 +_4 -_1 -_5 )
# + 0.014403922240614243 * ( +_4 +_4 -_2 -_2 )
# + 0.011843706720007043 * ( +_4 +_4 -_2 -_6 )
# + -0.006725730203450188 * ( +_4 +_4 -_3 -_0 )
# + -0.023452418504650734 * ( +_4 +_4 -_3 -_1 )
# + 0.02796423863002556 * ( +_4 +_4 -_3 -_3 )
# + -0.0008824631406980474 * ( +_4 +_4 -_3 -_5 )
# + 0.44007954668752236 * ( +_4 +_4 -_4 -_4 )
# + 0.007878382769591146 * ( +_4 +_4 -_5 -_0 )
# + 0.029567474567131626 * ( +_4 +_4 -_5 -_1 )
# + -0.0008824631406980523 * ( +_4 +_4 -_5 -_3 )
# + 0.019302468166266924 * ( +_4 +_4 -_5 -_5 )
# + 0.011843706720007043 * ( +_4 +_4 -_6 -_2 )
# + 0.012175088616844233 * ( +_4 +_4 -_6 -_6 )
# + -0.003105685015072105 * ( +_4 +_5 -_0 -_4 )
# + 0.07931265007419268 * ( +_4 +_5 -_1 -_4 )
# + 0.05809306215666278 * ( +_4 +_5 -_3 -_4 )
# + 0.007878382769591144 * ( +_4 +_5 -_4 -_0 )
# + 0.029567474567131623 * ( +_4 +_5 -_4 -_1 )
# ...
# + -0.003488567700165582 * ( +_12 +_7 -_8 -_12 )
# + 0.001574881852258903 * ( +_12 +_7 -_9 -_9 )
# + 0.004607388980076485 * ( +_12 +_7 -_9 -_13 )
# + -0.0002864078952772508 * ( +_12 +_7 -_10 -_7 )
# + 0.009325359416068667 * ( +_12 +_7 -_10 -_8 )
# + 0.0011744439184291284 * ( +_12 +_7 -_10 -_10 )
# + 0.010599008579304093 * ( +_12 +_7 -_10 -_12 )
# + 0.007878382769591146 * ( +_12 +_7 -_11 -_11 )
# + 0.01566308868120363 * ( +_12 +_7 -_12 -_7 )
# + 0.0033977498864339734 * ( +_12 +_7 -_12 -_8 )
# + -0.00013734154277089843 * ( +_12 +_7 -_12 -_10 )
# + 0.004201261578125714 * ( +_12 +_7 -_12 -_12 )
# + 0.0019322820936806186 * ( +_12 +_7 -_13 -_9 )
# + 0.006100835170006281 * ( +_12 +_7 -_13 -_13 )
# + 0.017907909335565717 * ( +_12 +_8 -_7 -_7 )
# + -0.0033248081065072326 * ( +_12 +_8 -_7 -_8 )
# + -0.0011145251113430057 * ( +_12 +_8 -_7 -_10 )
# + -0.003488567700165536 * ( +_12 +_8 -_7 -_12 )
# + -0.00039156406691045743 * ( +_12 +_8 -_8 -_7 )
# + 0.07146241830371053 * ( +_12 +_8 -_8 -_8 )
# + 0.04768771470539326 * ( +_12 +_8 -_8 -_10 )
# + 0.3070976806641894 * ( +_12 +_8 -_8 -_12 )
# + -0.020066409945183487 * ( +_12 +_8 -_9 -_9 )
# + 0.049321930536518135 * ( +_12 +_8 -_9 -_13 )
# + 0.01017008032659659 * ( +_12 +_8 -_10 -_7 )
# + 0.010473174371252234 * ( +_12 +_8 -_10 -_8 )
# + -0.015664962510669168 * ( +_12 +_8 -_10 -_10 )
# + 0.029308499457380524 * ( +_12 +_8 -_10 -_12 )
# + 0.029567474567131633 * ( +_12 +_8 -_11 -_11 )
# + 0.0033977498864339864 * ( +_12 +_8 -_12 -_7 )
# + 0.050952969695442406 * ( +_12 +_8 -_12 -_8 )
# + 0.030486772061777728 * ( +_12 +_8 -_12 -_10 )
# + 0.04838785264956784 * ( +_12 +_8 -_12 -_12 )
# + 0.01767124663053722 * ( +_12 +_8 -_13 -_9 )
# + -0.004977329876101968 * ( +_12 +_8 -_13 -_13 )
# + 0.0015748818522589056 * ( +_12 +_9 -_7 -_9 )
# + 0.004607388980076483 * ( +_12 +_9 -_7 -_13 )
# + -0.020066409945183463 * ( +_12 +_9 -_8 -_9 )
# + 0.04932193053651815 * ( +_12 +_9 -_8 -_13 )
# + 9.850026333892277e-05 * ( +_12 +_9 -_9 -_7 )
# + 0.037944575775745906 * ( +_12 +_9 -_9 -_8 )
# + 0.021613099012109685 * ( +_12 +_9 -_9 -_10 )
# + 0.28574723391233425 * ( +_12 +_9 -_9 -_12 )
# + -0.0142931779949586 * ( +_12 +_9 -_10 -_9 )
# + 0.02380754525594561 * ( +_12 +_9 -_10 -_13 )
# + 0.03546339523637597 * ( +_12 +_9 -_12 -_9 )
# + -0.03226403027597525 * ( +_12 +_9 -_12 -_13 )
# + -0.0034949837829906733 * ( +_12 +_9 -_13 -_7 )
# + 0.03838066507689978 * ( +_12 +_9 -_13 -_8 )
# + 0.039199575704259325 * ( +_12 +_9 -_13 -_10 )
# + 0.018965849698030734 * ( +_12 +_9 -_13 -_12 )
# + -0.00028640789527724695 * ( +_12 +_10 -_7 -_7 )
# + 0.00932535941606868 * ( +_12 +_10 -_7 -_8 )
# + 0.0011744439184291264 * ( +_12 +_10 -_7 -_10 )
# + 0.010599008579304077 * ( +_12 +_10 -_7 -_12 )
# + 0.010170080326596604 * ( +_12 +_10 -_8 -_7 )
# + 0.010473174371252263 * ( +_12 +_10 -_8 -_8 )
# + -0.015664962510669157 * ( +_12 +_10 -_8 -_10 )
# + 0.02930849945738053 * ( +_12 +_10 -_8 -_12 )
# + -0.014293177994958585 * ( +_12 +_10 -_9 -_9 )
# + 0.02380754525594559 * ( +_12 +_10 -_9 -_13 )
# + -0.009621901749820562 * ( +_12 +_10 -_10 -_7 )
# + 0.044144052827674675 * ( +_12 +_10 -_10 -_8 )
# + 0.06065508065913003 * ( +_12 +_10 -_10 -_10 )
# + 0.27453166790402445 * ( +_12 +_10 -_10 -_12 )
# + -0.0008824631406980525 * ( +_12 +_10 -_11 -_11 )
# + -0.00013734154277089805 * ( +_12 +_10 -_12 -_7 )
# + 0.030486772061777682 * ( +_12 +_10 -_12 -_8 )
# + 0.0343174914565155 * ( +_12 +_10 -_12 -_10 )
# + 0.022285875045437473 * ( +_12 +_10 -_12 -_12 )
# + 0.02221198585056198 * ( +_12 +_10 -_13 -_9 )
# + -0.028952272315813266 * ( +_12 +_10 -_13 -_13 )
# + 0.007878382769591151 * ( +_12 +_11 -_7 -_11 )
# + 0.029567474567131623 * ( +_12 +_11 -_8 -_11 )
# + -0.0008824631406980462 * ( +_12 +_11 -_10 -_11 )
# + -0.003105685015072038 * ( +_12 +_11 -_11 -_7 )
# + 0.07931265007419264 * ( +_12 +_11 -_11 -_8 )
# + 0.058093062156662836 * ( +_12 +_11 -_11 -_10 )
# + 0.29447725138741204 * ( +_12 +_11 -_11 -_12 )
# + 0.019302468166266927 * ( +_12 +_11 -_12 -_11 )
# + 0.015663088681203623 * ( +_12 +_12 -_7 -_7 )
# + 0.0033977498864339608 * ( +_12 +_12 -_7 -_8 )
# + -0.0001373415427708922 * ( +_12 +_12 -_7 -_10 )
# + 0.004201261578125741 * ( +_12 +_12 -_7 -_12 )
# + 0.0033977498864339642 * ( +_12 +_12 -_8 -_7 )
# + 0.05095296969544236 * ( +_12 +_12 -_8 -_8 )
# + 0.030486772061777682 * ( +_12 +_12 -_8 -_10 )
# + 0.04838785264956773 * ( +_12 +_12 -_8 -_12 )
# + 0.03546339523637596 * ( +_12 +_12 -_9 -_9 )
# + -0.032264030275975276 * ( +_12 +_12 -_9 -_13 )
# + -0.00013734154277089623 * ( +_12 +_12 -_10 -_7 )
# + 0.030486772061777672 * ( +_12 +_12 -_10 -_8 )
# + 0.034317491456515505 * ( +_12 +_12 -_10 -_10 )
# + 0.02228587504543745 * ( +_12 +_12 -_10 -_12 )
# + 0.019302468166266927 * ( +_12 +_12 -_11 -_11 )
# + 0.004201261578125815 * ( +_12 +_12 -_12 -_7 )
# + 0.048387852649567915 * ( +_12 +_12 -_12 -_8 )
# + 0.022285875045437428 * ( +_12 +_12 -_12 -_10 )
# + 0.29856910242082674 * ( +_12 +_12 -_12 -_12 )
# + -0.03226403027597521 * ( +_12 +_12 -_13 -_9 )
# + 0.05766403665298247 * ( +_12 +_12 -_13 -_13 )
# + 0.0019322820936806223 * ( +_12 +_13 -_7 -_9 )
# + 0.006100835170006282 * ( +_12 +_13 -_7 -_13 )
# + 0.017671246630537204 * ( +_12 +_13 -_8 -_9 )
# + -0.004977329876101947 * ( +_12 +_13 -_8 -_13 )
# + -0.0034949837829906737 * ( +_12 +_13 -_9 -_7 )
# + 0.03838066507689977 * ( +_12 +_13 -_9 -_8 )
# + 0.039199575704259325 * ( +_12 +_13 -_9 -_10 )
# + 0.018965849698030748 * ( +_12 +_13 -_9 -_12 )
# + 0.022211985850562017 * ( +_12 +_13 -_10 -_9 )
# + -0.028952272315813352 * ( +_12 +_13 -_10 -_13 )
# + -0.03226403027597527 * ( +_12 +_13 -_12 -_9 )
# + 0.05766403665298251 * ( +_12 +_13 -_12 -_13 )
# + -0.002566730736030651 * ( +_12 +_13 -_13 -_7 )
# + 0.03453719028495609 * ( +_12 +_13 -_13 -_8 )
# + 0.02075898004754377 * ( +_12 +_13 -_13 -_10 )
# + 0.283172031253365 * ( +_12 +_13 -_13 -_12 )
# + 0.18120093908141952 * ( +_13 +_0 -_0 -_9 )
# + 0.43454263558431594 * ( +_13 +_0 -_0 -_13 )
# + -0.0037527659391431373 * ( +_13 +_0 -_1 -_9 )
# + -0.00470159832236412 * ( +_13 +_0 -_1 -_13 )
# + 0.007659485869533508 * ( +_13 +_0 -_2 -_7 )
# + 0.00693784535929103 * ( +_13 +_0 -_2 -_8 )
# + -0.004818402181974995 * ( +_13 +_0 -_2 -_10 )
# + 0.004607388980076484 * ( +_13 +_0 -_2 -_12 )
# + -0.0004129409973065917 * ( +_13 +_0 -_3 -_9 )
# + 0.0020845295921363034 * ( +_13 +_0 -_3 -_13 )
# + -0.0034949837829906685 * ( +_13 +_0 -_5 -_9 )
# + -0.002566730736030755 * ( +_13 +_0 -_5 -_13 )
# + 0.010700382853445958 * ( +_13 +_0 -_6 -_7 )
# + 0.009153660346168525 * ( +_13 +_0 -_6 -_8 )
# + -0.006602180403890651 * ( +_13 +_0 -_6 -_10 )
# + 0.006100835170006281 * ( +_13 +_0 -_6 -_12 )
# + -0.0037527659391431425 * ( +_13 +_1 -_0 -_9 )
# + -0.0047015983223641184 * ( +_13 +_1 -_0 -_13 )
# + 0.06912488033573728 * ( +_13 +_1 -_1 -_9 )
# + 0.3121458601051433 * ( +_13 +_1 -_1 -_13 )
# + 0.011554962723641277 * ( +_13 +_1 -_2 -_7 )
# + 0.020153286914855715 * ( +_13 +_1 -_2 -_8 )
# + -0.03854895993709509 * ( +_13 +_1 -_2 -_10 )
# + 0.04932193053651812 * ( +_13 +_1 -_2 -_12 )
# + -0.03810831361009277 * ( +_13 +_1 -_3 -_9 )
# + -0.006910419847961711 * ( +_13 +_1 -_3 -_13 )
# + 0.03838066507689992 * ( +_13 +_1 -_5 -_9 )
# + 0.03453719028495596 * ( +_13 +_1 -_5 -_13 )
# + 0.009153660346168527 * ( +_13 +_1 -_6 -_7 )
# + 0.03094716220073635 * ( +_13 +_1 -_6 -_8 )
# + -0.008335962519316729 * ( +_13 +_1 -_6 -_10 )
# + -0.004977329876101954 * ( +_13 +_1 -_6 -_12 )
# + 0.007659485869533511 * ( +_13 +_2 -_0 -_7 )
# + 0.0069378453592910325 * ( +_13 +_2 -_0 -_8 )
# + -0.004818402181974998 * ( +_13 +_2 -_0 -_10 )
# + 0.004607388980076483 * ( +_13 +_2 -_0 -_12 )
# + 0.011554962723641284 * ( +_13 +_2 -_1 -_7 )
# + 0.02015328691485572 * ( +_13 +_2 -_1 -_8 )
# + -0.03854895993709511 * ( +_13 +_2 -_1 -_10 )
# + 0.04932193053651812 * ( +_13 +_2 -_1 -_12 )
# + 0.045211651005135356 * ( +_13 +_2 -_2 -_9 )
# + 0.30541723252526665 * ( +_13 +_2 -_2 -_13 )
# + -0.002481213223072597 * ( +_13 +_2 -_3 -_7 )
# + -0.01703839755363644 * ( +_13 +_2 -_3 -_8 )
# + 0.0011628804655886373 * ( +_13 +_2 -_3 -_10 )
# + 0.023807545255945625 * ( +_13 +_2 -_3 -_12 )
# + 0.01184370672000704 * ( +_13 +_2 -_4 -_11 )
# + 0.001932282093680624 * ( +_13 +_2 -_5 -_7 )
# + 0.017671246630537214 * ( +_13 +_2 -_5 -_8 )
# + 0.02221198585056203 * ( +_13 +_2 -_5 -_10 )
# + -0.03226403027597527 * ( +_13 +_2 -_5 -_12 )
# + 0.07623119004546161 * ( +_13 +_2 -_6 -_9 )
# + 0.046613835113420446 * ( +_13 +_2 -_6 -_13 )
# + -0.00041294099730658295 * ( +_13 +_3 -_0 -_9 )
# + 0.0020845295921362974 * ( +_13 +_3 -_0 -_13 )
# + -0.03810831361009276 * ( +_13 +_3 -_1 -_9 )
# + -0.006910419847961745 * ( +_13 +_3 -_1 -_13 )
# + -0.0024812132230725946 * ( +_13 +_3 -_2 -_7 )
# + -0.017038397553636443 * ( +_13 +_3 -_2 -_8 )
# + 0.001162880465588633 * ( +_13 +_3 -_2 -_10 )
# + 0.0238075452559456 * ( +_13 +_3 -_2 -_12 )
# + 0.08004713990682993 * ( +_13 +_3 -_3 -_9 )
# + 0.3041614868011194 * ( +_13 +_3 -_3 -_13 )
# + 0.03919957570425923 * ( +_13 +_3 -_5 -_9 )
# + 0.020758980047543767 * ( +_13 +_3 -_5 -_13 )
# + -0.0066021804038906475 * ( +_13 +_3 -_6 -_7 )
# + -0.008335962519316703 * ( +_13 +_3 -_6 -_8 )
# + 0.034478813806152586 * ( +_13 +_3 -_6 -_10 )
# + -0.02895227231581326 * ( +_13 +_3 -_6 -_12 )
# + 0.01184370672000704 * ( +_13 +_4 -_2 -_11 )
# + 0.0948947501743813 * ( +_13 +_4 -_4 -_9 )
# + 0.31252696603649777 * ( +_13 +_4 -_4 -_13 )
# + 0.012175088616844238 * ( +_13 +_4 -_6 -_11 )
# + -0.0034949837829906794 * ( +_13 +_5 -_0 -_9 )
# + -0.0025667307360307486 * ( +_13 +_5 -_0 -_13 )
# + 0.038380665076899925 * ( +_13 +_5 -_1 -_9 )
# + 0.03453719028495602 * ( +_13 +_5 -_1 -_13 )
# + 0.0019322820936806186 * ( +_13 +_5 -_2 -_7 )
# + 0.017671246630537242 * ( +_13 +_5 -_2 -_8 )
# + 0.022211985850562038 * ( +_13 +_5 -_2 -_10 )
# + -0.03226403027597528 * ( +_13 +_5 -_2 -_12 )
# + 0.03919957570425926 * ( +_13 +_5 -_3 -_9 )
# + 0.020758980047543743 * ( +_13 +_5 -_3 -_13 )
# + 0.018965849698030945 * ( +_13 +_5 -_5 -_9 )
# + 0.28317203125336476 * ( +_13 +_5 -_5 -_13 )
# + 0.006100835170006292 * ( +_13 +_5 -_6 -_7 )
# + -0.004977329876101929 * ( +_13 +_5 -_6 -_8 )
# + -0.028952272315813356 * ( +_13 +_5 -_6 -_10 )
# + 0.05766403665298246 * ( +_13 +_5 -_6 -_12 )
# + 0.01070038285344596 * ( +_13 +_6 -_0 -_7 )
# + 0.009153660346168532 * ( +_13 +_6 -_0 -_8 )
# + -0.006602180403890652 * ( +_13 +_6 -_0 -_10 )
# + 0.006100835170006286 * ( +_13 +_6 -_0 -_12 )
# + 0.009153660346168527 * ( +_13 +_6 -_1 -_7 )
# + 0.03094716220073636 * ( +_13 +_6 -_1 -_8 )
# + -0.008335962519316726 * ( +_13 +_6 -_1 -_10 )
# + -0.004977329876101927 * ( +_13 +_6 -_1 -_12 )
# + 0.07623119004546164 * ( +_13 +_6 -_2 -_9 )
# + 0.04661383511342045 * ( +_13 +_6 -_2 -_13 )
# + -0.006602180403890644 * ( +_13 +_6 -_3 -_7 )
# + -0.008335962519316693 * ( +_13 +_6 -_3 -_8 )
# + 0.034478813806152586 * ( +_13 +_6 -_3 -_10 )
# + -0.028952272315813342 * ( +_13 +_6 -_3 -_12 )
# + 0.01217508861684424 * ( +_13 +_6 -_4 -_11 )
# + 0.006100835170006289 * ( +_13 +_6 -_5 -_7 )
# + -0.004977329876101977 * ( +_13 +_6 -_5 -_8 )
# + -0.028952272315813328 * ( +_13 +_6 -_5 -_10 )
# + 0.057664036652982475 * ( +_13 +_6 -_5 -_12 )
# + 0.046613835113420495 * ( +_13 +_6 -_6 -_9 )
# + 0.3098012295576644 * ( +_13 +_6 -_6 -_13 )
# + 0.18120093908141952 * ( +_13 +_7 -_7 -_9 )
# + 0.43454263558431594 * ( +_13 +_7 -_7 -_13 )
# + -0.0037527659391431373 * ( +_13 +_7 -_8 -_9 )
# + -0.00470159832236412 * ( +_13 +_7 -_8 -_13 )
# + 0.007659485869533508 * ( +_13 +_7 -_9 -_7 )
# + 0.00693784535929103 * ( +_13 +_7 -_9 -_8 )
# + -0.004818402181974995 * ( +_13 +_7 -_9 -_10 )
# + 0.004607388980076484 * ( +_13 +_7 -_9 -_12 )
# + -0.0004129409973065917 * ( +_13 +_7 -_10 -_9 )
# + 0.0020845295921363034 * ( +_13 +_7 -_10 -_13 )
# + -0.0034949837829906685 * ( +_13 +_7 -_12 -_9 )
# + -0.002566730736030755 * ( +_13 +_7 -_12 -_13 )
# + 0.010700382853445958 * ( +_13 +_7 -_13 -_7 )
# + 0.009153660346168525 * ( +_13 +_7 -_13 -_8 )
# + -0.006602180403890651 * ( +_13 +_7 -_13 -_10 )
# + 0.006100835170006281 * ( +_13 +_7 -_13 -_12 )
# + -0.0037527659391431425 * ( +_13 +_8 -_7 -_9 )
# + -0.0047015983223641184 * ( +_13 +_8 -_7 -_13 )
# + 0.06912488033573728 * ( +_13 +_8 -_8 -_9 )
# + 0.3121458601051433 * ( +_13 +_8 -_8 -_13 )
# + 0.011554962723641277 * ( +_13 +_8 -_9 -_7 )
# + 0.020153286914855715 * ( +_13 +_8 -_9 -_8 )
# + -0.03854895993709509 * ( +_13 +_8 -_9 -_10 )
# + 0.04932193053651812 * ( +_13 +_8 -_9 -_12 )
# + -0.03810831361009277 * ( +_13 +_8 -_10 -_9 )
# + -0.006910419847961711 * ( +_13 +_8 -_10 -_13 )
# + 0.03838066507689992 * ( +_13 +_8 -_12 -_9 )
# + 0.03453719028495596 * ( +_13 +_8 -_12 -_13 )
# + 0.009153660346168527 * ( +_13 +_8 -_13 -_7 )
# + 0.03094716220073635 * ( +_13 +_8 -_13 -_8 )
# + -0.008335962519316729 * ( +_13 +_8 -_13 -_10 )
# + -0.004977329876101954 * ( +_13 +_8 -_13 -_12 )
# + 0.007659485869533511 * ( +_13 +_9 -_7 -_7 )
# + 0.0069378453592910325 * ( +_13 +_9 -_7 -_8 )
# + -0.004818402181974998 * ( +_13 +_9 -_7 -_10 )
# + 0.004607388980076483 * ( +_13 +_9 -_7 -_12 )
# + 0.011554962723641284 * ( +_13 +_9 -_8 -_7 )
# + 0.02015328691485572 * ( +_13 +_9 -_8 -_8 )
# + -0.03854895993709511 * ( +_13 +_9 -_8 -_10 )
# + 0.04932193053651812 * ( +_13 +_9 -_8 -_12 )
# + 0.045211651005135356 * ( +_13 +_9 -_9 -_9 )
# + 0.30541723252526665 * ( +_13 +_9 -_9 -_13 )
# + -0.002481213223072597 * ( +_13 +_9 -_10 -_7 )
# + -0.01703839755363644 * ( +_13 +_9 -_10 -_8 )
# + 0.0011628804655886373 * ( +_13 +_9 -_10 -_10 )
# + 0.023807545255945625 * ( +_13 +_9 -_10 -_12 )
# + 0.01184370672000704 * ( +_13 +_9 -_11 -_11 )
# + 0.001932282093680624 * ( +_13 +_9 -_12 -_7 )
# + 0.017671246630537214 * ( +_13 +_9 -_12 -_8 )
# + 0.02221198585056203 * ( +_13 +_9 -_12 -_10 )
# + -0.03226403027597527 * ( +_13 +_9 -_12 -_12 )
# + 0.07623119004546161 * ( +_13 +_9 -_13 -_9 )
# + 0.046613835113420446 * ( +_13 +_9 -_13 -_13 )
# + -0.00041294099730658295 * ( +_13 +_10 -_7 -_9 )
# + 0.0020845295921362974 * ( +_13 +_10 -_7 -_13 )
# + -0.03810831361009276 * ( +_13 +_10 -_8 -_9 )
# + -0.006910419847961745 * ( +_13 +_10 -_8 -_13 )
# + -0.0024812132230725946 * ( +_13 +_10 -_9 -_7 )
# + -0.017038397553636443 * ( +_13 +_10 -_9 -_8 )
# + 0.001162880465588633 * ( +_13 +_10 -_9 -_10 )
# + 0.0238075452559456 * ( +_13 +_10 -_9 -_12 )
# + 0.08004713990682993 * ( +_13 +_10 -_10 -_9 )
# + 0.3041614868011194 * ( +_13 +_10 -_10 -_13 )
# + 0.03919957570425923 * ( +_13 +_10 -_12 -_9 )
# + 0.020758980047543767 * ( +_13 +_10 -_12 -_13 )
# + -0.0066021804038906475 * ( +_13 +_10 -_13 -_7 )
# + -0.008335962519316703 * ( +_13 +_10 -_13 -_8 )
# + 0.034478813806152586 * ( +_13 +_10 -_13 -_10 )
# + -0.02895227231581326 * ( +_13 +_10 -_13 -_12 )
# + 0.01184370672000704 * ( +_13 +_11 -_9 -_11 )
# + 0.0948947501743813 * ( +_13 +_11 -_11 -_9 )
# + 0.31252696603649777 * ( +_13 +_11 -_11 -_13 )
# + 0.012175088616844238 * ( +_13 +_11 -_13 -_11 )
# + -0.0034949837829906794 * ( +_13 +_12 -_7 -_9 )
# + -0.0025667307360307486 * ( +_13 +_12 -_7 -_13 )
# + 0.038380665076899925 * ( +_13 +_12 -_8 -_9 )
# + 0.03453719028495602 * ( +_13 +_12 -_8 -_13 )
# + 0.0019322820936806186 * ( +_13 +_12 -_9 -_7 )
# + 0.017671246630537242 * ( +_13 +_12 -_9 -_8 )
# + 0.022211985850562038 * ( +_13 +_12 -_9 -_10 )
# + -0.03226403027597528 * ( +_13 +_12 -_9 -_12 )
# + 0.03919957570425926 * ( +_13 +_12 -_10 -_9 )
# + 0.020758980047543743 * ( +_13 +_12 -_10 -_13 )
# + 0.018965849698030945 * ( +_13 +_12 -_12 -_9 )
# + 0.28317203125336476 * ( +_13 +_12 -_12 -_13 )
# + 0.006100835170006292 * ( +_13 +_12 -_13 -_7 )
# + -0.004977329876101929 * ( +_13 +_12 -_13 -_8 )
# + -0.028952272315813356 * ( +_13 +_12 -_13 -_10 )
# + 0.05766403665298246 * ( +_13 +_12 -_13 -_12 )
# + 0.01070038285344596 * ( +_13 +_13 -_7 -_7 )
# + 0.009153660346168532 * ( +_13 +_13 -_7 -_8 )
# + -0.006602180403890652 * ( +_13 +_13 -_7 -_10 )
# + 0.006100835170006286 * ( +_13 +_13 -_7 -_12 )
# + 0.009153660346168527 * ( +_13 +_13 -_8 -_7 )
# + 0.03094716220073636 * ( +_13 +_13 -_8 -_8 )
# + -0.008335962519316726 * ( +_13 +_13 -_8 -_10 )
# + -0.004977329876101927 * ( +_13 +_13 -_8 -_12 )
# + 0.07623119004546164 * ( +_13 +_13 -_9 -_9 )
# + 0.04661383511342045 * ( +_13 +_13 -_9 -_13 )
# + -0.006602180403890644 * ( +_13 +_13 -_10 -_7 )
# + -0.008335962519316693 * ( +_13 +_13 -_10 -_8 )
# + 0.034478813806152586 * ( +_13 +_13 -_10 -_10 )
# + -0.028952272315813342 * ( +_13 +_13 -_10 -_12 )
# + 0.01217508861684424 * ( +_13 +_13 -_11 -_11 )
# + 0.006100835170006289 * ( +_13 +_13 -_12 -_7 )
# + -0.004977329876101977 * ( +_13 +_13 -_12 -_8 )
# + -0.028952272315813328 * ( +_13 +_13 -_12 -_10 )
# + 0.057664036652982475 * ( +_13 +_13 -_12 -_12 )
# + 0.046613835113420495 * ( +_13 +_13 -_13 -_9 )
# + 0.3098012295576644 * ( +_13 +_13 -_13 -_13 )

# %% [markdown]
# - Convert Fermionic op to qubit hamiltonian

# %%
qubit_mapper = ParityMapper(num_particles=electronic_structure_problem.num_particles)
qubit_hamiltonian = qubit_mapper.map(FermionicOpWithCoefficients)

print(qubit_hamiltonian)
print('No of qubits required for the solution : ', qubit_hamiltonian.num_qubits)
# Out:
# SparsePauliOp(['IIIIIIIIIIII', 'IIIIIIIIIIIZ', 'IIIIIIIIIIZX', 'IIIIIIIIIIIX', 'IIIIIIIIZXXX', 'IIIIIIIIIYXY', 'IIIIIIZXXXXX', 'IIIIIIIYXXXY', 'IIIIIIIIIIZZ', 'IIIIIIIIZXXZ', 'IIIIIIIIIYYI', 'IIIIIIZXXXXZ', 'IIIIIIIYXXYI', 'IIIIIIIIIZZI', 'IIIIIIXXXXZI', 'IIIIIIYXXYII', 'IIIIIIIIZZII', 'IIIIIIZXXZII', 'IIIIIIIYYIII', 'IIIIIIIZZIII', 'IIIIIIZZIIII', 'IIIIIIZIIIII', 'IIIIIZIIIIII', 'IIIIZXIIIIII', 'IIIIIXIIIIII', 'IIZXXXIIIIII', 'IIIYXYIIIIII', 'ZXXXXXIIIIII', 'IYXXXYIIIIII', 'IIIIZZIIIIII', 'IIZXXZIIIIII', 'IIIYYIIIIIII', 'ZXXXXZIIIIII', 'IYXXYIIIIIII', 'IIIZZIIIIIII', 'XXXXZIIIIIII', 'YXXYIIIIIIII', 'IIZZIIIIIIII', 'ZXXZIIIIIIII', 'IYYIIIIIIIII', 'IZZIIIIIIIII', 'ZZIIIIIIIIII', 'ZIIIIIIIIIII', 'IIIIIIIIIIZI', 'IIIIIIIIZXXI', 'IIIIIIIIIYYZ', 'IIIIIIZXXXXI', 'IIIIIIIYXXYZ', 'IIIIIIIIZXYY', 'IIIIIIIIIYYX', 'IIIIIIZXXXYY', 'IIIIIIIYXXYX', 'IIIIIIXXXYIY', 'IIIIIIXXXXIX', 'IIIIIIYXXYZX', 'IIIIIIXXXXZX', 'IIIIIIYXXYIX', 'IIIIIIYXXXIY', 'IIIIIIZXYIIY', 'IIIIIIZXXZZX', 'IIIIIIIYYIZX', 'IIIIIIZXXZIX', 'IIIIIIIYYIIX', 'IIIIIIIYXZZY', 'IIIIIIIIIZZZ', 'IIIIIIXXXXZZ', 'IIIIIIYXXYIZ', 'IIIIIIIIIZIX', 'IIIIIIIIIZZX', 'IIIIIIIIZYYX', 'IIIIIIIIIXYY', 'IIIIIIZXXYYX', 'IIIIIIIYXYYY', 'IIIIIIXXYIYX', 'IIIIIIXXXIXX', 'IIIIIIYXYZXX', 'IIIIIIXXXZYY', 'IIIIIIYXYIYY', 'IIIIIIYXXIXY', 'IIIIIIYIIIYX', 'IIIIIIXZIZXX', 'IIIIIIXIIZXX', 'IIIIIIXZIIYY', 'IIIIIIXIIIYY', 'IIIIIIYZIZXY', 'IIIIIIIIZZIZ', 'IIIIIIZXXZIZ', 'IIIIIIIYYIIZ', 'IIIIIIIIZZZX', 'IIIIIIIIZZIX', 'IIIIIIZXYYXX', 'IIIIIIIYYYXY', 'IIIIIIIZZIIZ', 'IIIIIIIZZIZX', 'IIIIIIIZZIIX', 'IIIIIIIZIXXX', 'IIIIIIIZZYXY', 'IIIIIIZYYXXX', 'IIIIIIIXYXXY', 'IIIIIIZZIIIZ', 'IIIIIIZZIIZX', 'IIIIIIZZIIIX', 'IIIIIIZZZXXX', 'IIIIIIZZIYXY', 'IIIIIIZIIIIZ', 'IIIIIIZIIIZX', 'IIIIIIZIIIIX', 'IIIIIIZIZXXX', 'IIIIIIZIIYXY', 'IIIIIIIXXXXX', 'IIIIIIZYXXXY', 'IIIIIZIIIIIZ', 'IIIIIZIIIIZX', 'IIIIIZIIIIIX', 'IIIIIZIIZXXX', 'IIIIIZIIIYXY', 'IIIIIZZXXXXX', 'IIIIIZIYXXXY', 'IIIIZXIIIIIZ', 'IIIIIXIIIIIZ', 'IIIIZXIIIIZX', 'IIIIIXIIIIZX', 'IIIIZXIIIIIX', 'IIIIIXIIIIIX', 'IIIIZXIIZXXX', 'IIIIIXIIZXXX', 'IIIIZXIIIYXY', 'IIIIIXIIIYXY', 'IIIIZXZXXXXX', 'IIIIIXZXXXXX', 'IIIIZXIYXXXY', 'IIIIIXIYXXXY', 'IIIZXXIIIZXX', 'IIIIYYIIIZXX', 'IIIZXXIIIIYY', 'IIIIYYIIIIYY', 'IIIZXXXXXXXX', 'IIIIYYXXXXXX', 'IIIZXXYXXXXY', 'IIIIYYYXXXXY', 'IIZXXXIIIIIZ', 'IIIYXYIIIIIZ', 'IIZXXXIIIIZX', 'IIIYXYIIIIZX', 'IIZXXXIIIIIX', 'IIIYXYIIIIIX', 'IIZXXXIIZXXX', 'IIIYXYIIZXXX', 'IIZXXXIIIYXY', 'IIIYXYIIIYXY', 'IIZXXXZXXXXX', 'IIIYXYZXXXXX', 'IIZXXXIYXXXY', 'IIIYXYIYXXXY', 'IZXXXXIZXXXX', 'IIYXXYIZXXXX', 'IZXXXXIIYXXY', 'IIYXXYIIYXXY', 'ZXXXXXIIIIIZ', 'IYXXXYIIIIIZ', 'ZXXXXXIIIIZX', 'IYXXXYIIIIZX', 'ZXXXXXIIIIIX', 'IYXXXYIIIIIX', 'ZXXXXXIIZXXX', 'IYXXXYIIZXXX', 'ZXXXXXIIIYXY', 'IYXXXYIIIYXY', 'ZXXXXXZXXXXX', 'IYXXXYZXXXXX', 'ZXXXXXIYXXXY', 'IYXXXYIYXXXY', 'XXXXXXIIIZXX', 'YXXXXYIIIZXX', 'XXXXXXIIIIYY', 'YXXXXYIIIIYY', 'XXXXXXXXXXXX', 'YXXXXYXXXXXX', 'XXXXXXYXXXXY', 'YXXXXYYXXXXY', 'IIIIZZIIIIIZ', 'IIIIZZIIIIZX', 'IIIIZZIIIIIX', 'IIIIZZIIZXXX', 'IIIIZZIIIYXY', 'IIIIZZZXXXXX', 'IIIIZZIYXXXY', 'IIIZXZIIIZXX', 'IIIIXIIIIZXX', 'IIIZXZIIIIYY', 'IIIIXIIIIIYY', 'IIIZXZXXXXXX', 'IIIIXIXXXXXX', 'IIIZXZYXXXXY', 'IIIIXIYXXXXY', 'IIZXXZIIIIIZ', 'IIIYYIIIIIIZ', 'IIZXXZIIIIZX', 'IIIYYIIIIIZX', 'IIZXXZIIIIIX', 'IIIYYIIIIIIX', 'IIZXXZIIZXXX', 'IIIYYIIIZXXX', 'IIZXXZIIIYXY', 'IIIYYIIIIYXY', 'IIZXXZZXXXXX', 'IIIYYIZXXXXX', 'IIZXXZIYXXXY', 'IIIYYIIYXXXY', 'IZXXXZIZXXXX', 'IIYXYIIZXXXX', 'IZXXXZIIYXXY', 'IIYXYIIIYXXY', 'ZXXXXZIIIIIZ', 'IYXXYIIIIIIZ', 'ZXXXXZIIIIZX', 'IYXXYIIIIIZX', 'ZXXXXZIIIIIX', 'IYXXYIIIIIIX', 'ZXXXXZIIZXXX', 'IYXXYIIIZXXX', 'ZXXXXZIIIYXY', 'IYXXYIIIIYXY', 'ZXXXXZZXXXXX', 'IYXXYIZXXXXX', 'ZXXXXZIYXXXY', 'IYXXYIIYXXXY', 'XXXXXZIIIZXX', 'YXXXYIIIIZXX', 'XXXXXZIIIIYY', 'YXXXYIIIIIYY', 'XXXXXZXXXXXX', 'YXXXYIXXXXXX', 'XXXXXZYXXXXY', 'YXXXYIYXXXXY', 'IIIZZIIIIIIZ', 'IIIZZIIIIIZX', 'IIIZZIIIIIIX', 'IIIZZIIIZXXX', 'IIIZZIIIIYXY', 'IIIZZIZXXXXX', 'IIIZZIIYXXXY', 'IIZXZIIIIZXX', 'IIIXIIIIIZXX', 'IIZXZIIIIIYY', 'IIIXIIIIIIYY', 'IIZXZIXXXXXX', 'IIIXIIXXXXXX', 'IIZXZIYXXXXY', ' ...
#               coeffs=[-55.61460307+0.j,  12.41351635+0.j,  -0.12505756+0.j, ...,
#    0.13758739+0.j,   0.15017594+0.j,   0.112754  +0.j])
# No of qubits required for the solution :  12

# %% [markdown]
# - Use active space transformer to convet the qubit requirement to 4.

# %%
# Activate space transformer
active_space_transformer = ActiveSpaceTransformer(num_electrons=2, num_spatial_orbitals=3)
electronic_structure_problem = active_space_transformer.transform(electronic_structure_problem)
qubit_mapper = ParityMapper(num_particles=electronic_structure_problem.num_particles)
qubit_hamiltonian = qubit_mapper.map(electronic_structure_problem.hamiltonian.second_q_op())
print('No of qubits required for the solution : ', qubit_hamiltonian.num_qubits)
# Out:
# No of qubits required for the solution :  4

# %%
from qiskit.algorithms.optimizers import COBYLA
from qiskit.algorithms.minimum_eigensolvers import VQE, NumPyMinimumEigensolver, MinimumEigensolverResult
from qiskit.primitives import Estimator

# %% [markdown]
# - Find the initial state to be fed into the VQE and ansatz

# %%
initial_state = HartreeFock(
    num_spatial_orbitals=electronic_structure_problem.num_spatial_orbitals, 
    num_particles=electronic_structure_problem.num_particles, 
    qubit_mapper=qubit_mapper)

ansatz = UCCSD(
    num_spatial_orbitals=electronic_structure_problem.num_spatial_orbitals, 
    num_particles=electronic_structure_problem.num_particles, 
    qubit_mapper=qubit_mapper, 
    initial_state=initial_state)

# %%
ansatz.decompose().draw(output="mpl", scale=0.5, fold=100)

# %%
ansatz.decompose().decompose().draw(output="mpl", scale=0.5, fold=100)

# %%
# Setup optimizer
optimizer = COBYLA(maxiter=2500)

energies = []
def callback(nfev, x, fx, *args):
    energies.append(fx)

# Setup VQE
estimator = Estimator()
vqe_solver = VQE(estimator, ansatz, optimizer, callback=callback)

# %%
# Solve for the groundstate
result = vqe_solver.compute_minimum_eigenvalue(qubit_hamiltonian)
result = electronic_structure_problem.interpret(result)

print (result)
# Out:
# === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -84.157310470574
#   - computed part:      -1.663095444866
#   - ActiveSpaceTransformer extracted energy part: -82.494215025708
# ~ Nuclear repulsion energy (Hartree): 9.193913160623
# > Total ground state energy (Hartree): -74.96339730995
#
# === MEASURED OBSERVABLES ===
#
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [0.0  2.21475902  0.0]

# %%
import matplotlib.pyplot as plt

plt.plot(energies, label='VQE')

plt.ylabel('Energy [Ha]', fontsize=14)
plt.xlabel('Optimization steps', fontsize=14)

plt.tick_params(which='both', labelsize=14)
plt.legend(fontsize=16)
plt.tight_layout()
