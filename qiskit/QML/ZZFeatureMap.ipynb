# %%
from qiskit import *
from qiskit.circuit.library import ZZFeatureMap
from qiskit.quantum_info import Statevector
QC = QuantumCircuit(3)
QC = ZZFeatureMap(3, reps = 1)
QC.decompose().draw(output='mpl', scale=0.5)

# %%
from qiskit import *
from qiskit.circuit.library import ZZFeatureMap
from qiskit.quantum_info import Statevector
QC = QuantumCircuit(3)
QC = ZZFeatureMap(3, reps = 1, entanglement='circular')
QC.decompose().draw(output='mpl', scale=0.5)
